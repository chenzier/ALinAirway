# %%
import numpy as np
import torch
import os
import skimage.io as io
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from torch import from_numpy as from_numpy
from matplotlib.colors import ListedColormap
import pickle
import sys
sys.path.append('../')  # 将上一层目录添加到模块搜索路径中
from func.model_arch2 import SegAirwayModel
from active_utils.random_crop import Random3DCrop_np,Normalization_np
from active_utils.get_embeddings import get_embeddings
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 12
#      10 import sys
#      11 sys.path.append('../')  # 将上一层目录添加到模块搜索路径中
# ---> 12 from func.model_arch2 import SegAirwayModel
#      13 from active_utils.random_crop import Random3DCrop_np,Normalization_np
#      14 from active_utils.get_embeddings import get_embeddings
#
# ModuleNotFoundError: No module named 'func'

# %%
## 加载数据

Precrop_dataset_for_train_path = "/mnt/wangc/EXACT09/Precrop_dataset_for_EXACT09_128"
Precrop_dataset_for_train_raw_path = Precrop_dataset_for_train_path+"/image"
Precrop_dataset_for_train_label_path = Precrop_dataset_for_train_path+"/label"

raw_case_name_list = os.listdir(Precrop_dataset_for_train_raw_path)
print(len(raw_case_name_list))
# raw_case_name_list = os.listdir(Precrop_dataset_for_train_label_path)


lidc_dataset_for_train_path='/mnt/wangc/LIDC/Precrop_dataset_for_LIDC-IDRI_128'
lidc_dataset_for_train_raw_path =lidc_dataset_for_train_path+"/image"
lidc_dataset_for_train_label_path = lidc_dataset_for_train_path+"/label"
lidc_raw_case_name_list = os.listdir(lidc_dataset_for_train_raw_path)
print(len(lidc_raw_case_name_list))
# Out:
# 8832
# 21760

# %%
crop_size = (32, 128, 128)
windowMin=-1000
windowMax=150
random3dcrop=Random3DCrop_np(crop_size)
normalization=Normalization_np(windowMin, windowMax)


device = torch.device('cuda:6' if torch.cuda.is_available() else 'cpu')
model=SegAirwayModel(in_channels=1, out_channels=2)
model.to(device)
load_pkl='/home/wangc/now/pure/checkpoint/abc_checkpoint_sample_org_33.pkl'
checkpoint = torch.load(load_pkl)
model.load_state_dict(checkpoint['model_state_dict'])
print(load_pkl)


N=len(lidc_raw_case_name_list)
# N=10
embeddings_list1, embeddings_dict1=get_embeddings(lidc_dataset_for_train_path,lidc_raw_case_name_list, 11760, model, device,
                                                only_positive=True,need_embedding=1
                                                )
# 将列表中的NumPy数组堆叠成一个NumPy数组
stacked_embeddings_numpy1 = np.stack(embeddings_list1, axis=0)
# Out:
# 8832
# 21760
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 84
#      14 print(len(lidc_raw_case_name_list))
#      18 # class Random3DCrop_np(object):
#      19 #     def __init__(self, output_size):
#      20 #         assert isinstance(output_size, (int, tuple)), 'Attention: random 3D crop output size: an int or a tuple (length:3)'
#    (...)
#      80 # random3dcrop=Random3DCrop_np(crop_size)
#      81 # normalization=Normalization_np(windowMin, windowMax)
# ---> 84 device = torch.device('cuda:6' if torch.cuda.is_available() else 'cpu')
#      85 model=SegAirwayModel(in_channels=1, out_channels=2)
#      86 model.to(device)
#
# File ~/anaconda3/envs/test1/lib/python3.8/site-packages/torch/cuda/__init__.py:82, in is_available()
#      79     return False
#      80 # This function never throws and returns 0 if driver is missing or can't
#      81 # be initialized
# ---> 82 return torch._C._cuda_getDeviceCount() > 0
#
# KeyboardInterrupt:

# %% [markdown]
# ## 正常的get embeddings在上面结束了，下面是做什么的呢？

# %%
print(stacked_embeddings_numpy1.shape)  # 输出应为 [N, 256, 4, 16, 16]

file_path1 = '/mnt/wangc/NaviAirway/saved_var/lidc_128_op_ae2_encoder1_data_a.pkl'
# 确保文件夹存在，如果不存在则创建它
os.makedirs(os.path.dirname(file_path1), exist_ok=True)

# 保存到文件
with open(file_path1, 'wb') as file:
    data_to_save = {'embeddings_list': embeddings_list1, 'embeddings_dict': embeddings_dict1}
    pickle.dump(data_to_save, file)

# %%
Precrop_dataset_for_train_path = "/mnt/wangc/EXACT09/Precrop_dataset_for_EXACT09_128"
Precrop_dataset_for_train_raw_path = Precrop_dataset_for_train_path+"/image"
Precrop_dataset_for_train_label_path = Precrop_dataset_for_train_path+"/label"

raw_case_name_list = os.listdir(Precrop_dataset_for_train_raw_path)
print(len(raw_case_name_list))
# raw_case_name_list = os.listdir(Precrop_dataset_for_train_label_path)


lidc_dataset_for_train_path='/mnt/wangc/LIDC/Precrop_dataset_for_LIDC-IDRI_128'
lidc_dataset_for_train_raw_path =lidc_dataset_for_train_path+"/image"
lidc_dataset_for_train_label_path = lidc_dataset_for_train_path+"/label"
lidc_raw_case_name_list = os.listdir(lidc_dataset_for_train_raw_path)
print(len(lidc_raw_case_name_list))



# class Random3DCrop_np(object):
#     def __init__(self, output_size):
#         assert isinstance(output_size, (int, tuple)), 'Attention: random 3D crop output size: an int or a tuple (length:3)'
#         if isinstance(output_size, int):
#             self.output_size=(output_size, output_size, output_size)
#         else:
#             assert len(output_size)==3, 'Attention: random 3D crop output size: a tuple (length:3)'
#             self.output_size=output_size
        
#     def random_crop_start_point(self, input_size):
#         assert len(input_size)==3, 'Attention: random 3D crop output size: a tuple (length:3)'
#         d, h, w=input_size
#         d_new, h_new, w_new=self.output_size
        
#         d_new = min(d, d_new)
#         h_new = min(h, h_new)
#         w_new = min(w, w_new)
        
#         assert (d>=d_new and h>=h_new and w>=w_new), "Attention: input size should >= crop size; now, input_size is "+str((d,h,w))+", while output_size is "+str((d_new, h_new, w_new))
        
#         d_start=np.random.randint(0, d-d_new+1)
#         h_start=np.random.randint(0, h-h_new+1)
#         w_start=np.random.randint(0, w-w_new+1)
        
#         return d_start, h_start, w_start
    
#     def __call__(self, img_3d, start_points=None):
#         img_3d=np.array(img_3d)
        
#         d, h, w=img_3d.shape
#         d_new, h_new, w_new=self.output_size
        
#         if start_points == None:
#             start_points = self.random_crop_start_point(img_3d.shape)
        
#         d_start, h_start, w_start = start_points
#         d_end = min(d_start+d_new, d)
#         h_end = min(h_start+h_new, h)
#         w_end = min(w_start+w_new, w)
        
#         crop=img_3d[d_start:d_end, h_start:h_end, w_start:w_end]
        
#         return crop

# class Normalization_np(object):
#     def __init__(self, windowMin, windowMax):
#         self.name = 'ManualNormalization'
#         assert isinstance(windowMax, (int,float))
#         assert isinstance(windowMin, (int,float))
#         self.windowMax = windowMax
#         self.windowMin = windowMin
    
#     def __call__(self, img_3d):
#         img_3d_norm = np.clip(img_3d, self.windowMin, self.windowMax)
#         img_3d_norm-=np.min(img_3d_norm)
#         max_99_val=np.percentile(img_3d_norm, 99)
#         if max_99_val>0:
#             img_3d_norm = img_3d_norm/max_99_val*255
#         return img_3d_norm
# crop_size = (32, 128, 128)
# windowMin=-1000
# windowMax=150
# random3dcrop=Random3DCrop_np(crop_size)
# normalization=Normalization_np(windowMin, windowMax)


device = torch.device('cuda:6' if torch.cuda.is_available() else 'cpu')
model=SegAirwayModel(in_channels=1, out_channels=2)
model.to(device)
load_pkl='/home/wangc/now/NaviAirway/checkpoint/abc_checkpoint_sample_org_33.pkl'
checkpoint = torch.load(load_pkl)
model.load_state_dict(checkpoint['model_state_dict'])
print(load_pkl)


def process_images1(Precrop_dataset_path,raw_case_name_list,M, N, 
                    model, device,random3dcrop=random3dcrop, normalization=normalization,
                   only_positive=False,#如果仅需要正例请选择
                   need_embedding=3
                   ):
    i =M
    embeddings_list = []  # 用于存储每个图像的 embeddings[3]
    embeddings_dict = {}

    for name in raw_case_name_list:
        if M<=i < N:
            i += 1
            img_addr = Precrop_dataset_path +"/image"+ "/" + name
            print(f'this is {i}')
            img = io.imread(img_addr, plugin='simpleitk')

            start_points = random3dcrop.random_crop_start_point(img.shape)  # 起点
            raw_img_crop = random3dcrop(np.array(img, float), start_points=start_points)
            raw_img_crop = normalization(raw_img_crop)
            raw_img_crop = np.expand_dims(raw_img_crop, axis=0)

            if only_positive is True:
                label_addr=Precrop_dataset_path +"/label"+ "/" + name
                label_img=io.imread(label_addr, plugin='simpleitk')
                if 1 in label_img:
                    b = from_numpy(raw_img_crop).float()
                    b = b.unsqueeze(0).to(device)
                    embeddings = model.get_embedding(b)
                    if 0<=need_embedding<len(embeddings):
                        emb = embeddings[need_embedding].cpu().detach().numpy()
                    else:
                        emb=model(b).cpu().detach().numpy()
                    embeddings_list.append(emb)  # 移动到CPU并转为NumPy后添加到列表
                    embeddings_dict[name] = emb
                    del b
            else:
                    b = from_numpy(raw_img_crop).float()
                    b = b.unsqueeze(0).to(device)
                    embeddings = model.get_embedding(b)
                    if 0<=need_embedding<len(embeddings):
                        emb = embeddings[need_embedding].cpu().detach().numpy()
                    else:
                        emb=model(b).cpu().detach().numpy()
                    embeddings_list.append(emb)  # 移动到CPU并转为NumPy后添加到列表
                    embeddings_dict[name] = emb
                    del b

    return embeddings_list, embeddings_dict
N=len(lidc_raw_case_name_list)
# N=10
embeddings_list2, embeddings_dict2=process_images1(lidc_dataset_for_train_path,lidc_raw_case_name_list, 11760,N, model, device,
                                                only_positive=True,need_embedding=1
                                                )
# 将列表中的NumPy数组堆叠成一个NumPy数组
stacked_embeddings_numpy2 = np.stack(embeddings_list1, axis=0)

# %%
print(stacked_embeddings_numpy2.shape)  # 输出应为 [N, 256, 4, 16, 16]

file_path2 = '/mnt/wangc/NaviAirway/saved_var/lidc_128_op_ae2_encoder2_data_b.pkl'
# 确保文件夹存在，如果不存在则创建它
os.makedirs(os.path.dirname(file_path2), exist_ok=True)

# 保存到文件
with open(file_path2, 'wb') as file:
    data_to_save = {'embeddings_list': embeddings_list2, 'embeddings_dict': embeddings_dict2}
    pickle.dump(data_to_save, file)

# %%
N=len(raw_case_name_list)
# N=10
embeddings_list, embeddings_dict=process_images(Precrop_dataset_for_train_path,raw_case_name_list, N, model, device,
                                                only_positive=True,need_embedding=1
                                                )
# 将列表中的NumPy数组堆叠成一个NumPy数组
stacked_embeddings_numpy = np.stack(embeddings_list, axis=0)
print(stacked_embeddings_numpy.shape)  # 输出应为 [N, 256, 4, 16, 16]

file_path = '/mnt/wangc/NaviAirway/saved_var/exact09_128_op_ae2_encoder1_data_b'
# 确保文件夹存在，如果不存在则创建它
os.makedirs(os.path.dirname(file_path), exist_ok=True)

# 保存到文件
with open(file_path, 'wb') as file:
    data_to_save = {'embeddings_list': embeddings_list, 'embeddings_dict': embeddings_dict}
    pickle.dump(data_to_save, file)
# Out:
# this is 1
# this is 2
# this is 3
# this is 4
# this is 5
# this is 6
# this is 7
# this is 8
# this is 9
# this is 10
# this is 11
# this is 12
# this is 13
# this is 14
# this is 15
# this is 16
# this is 17
# this is 18
# this is 19
# this is 20
# this is 21
# this is 22
# this is 23
# this is 24
# this is 25
# this is 26
# this is 27
# this is 28
# this is 29
# this is 30
# this is 31
# this is 32
# this is 33
# this is 34
# this is 35
# this is 36
# this is 37
# this is 38
# this is 39
# this is 40
# this is 41
# this is 42
# this is 43
# this is 44
# this is 45
# this is 46
# this is 47
# this is 48
# this is 49
# this is 50
# this is 51
# this is 52
# this is 53
# this is 54
# this is 55
# this is 56
# this is 57
# this is 58
# this is 59
# this is 60
# this is 61
# this is 62
# this is 63
# this is 64
# this is 65
# this is 66
# this is 67
# this is 68
# this is 69
# this is 70
# this is 71
# this is 72
# this is 73
# this is 74
# this is 75
# this is 76
# this is 77
# this is 78
# this is 79
# this is 80
# this is 81
# this is 82
# this is 83
# this is 84
# this is 85
# this is 86
# this is 87
# this is 88
# this is 89
# this is 90
# this is 91
# this is 92
# this is 93
# this is 94
# this is 95
# this is 96
# this is 97
# this is 98
# this is 99
# this is 100
# this is 101
# this is 102
# this is 103
# this is 104
# this is 105
# this is 106
# this is 107
# this is 108
# this is 109
# this is 110
# this is 111
# this is 112
# this is 113
# this is 114
# this is 115
# this is 116
# this is 117
# this is 118
# this is 119
# this is 120
# this is 121
# this is 122
# this is 123
# this is 124
# this is 125
# this is 126
# this is 127
# this is 128
# this is 129
# this is 130
# this is 131
# this is 132
# this is 133
# this is 134
# this is 135
# this is 136
# this is 137
# this is 138
# this is 139
# this is 140
# this is 141
# this is 142
# this is 143
# this is 144
# this is 145
# this is 146
# this is 147
# this is 148
# this is 149
# this is 150
# this is 151
# this is 152
# this is 153
# this is 154
# this is 155
# this is 156
# this is 157
# this is 158
# this is 159
# this is 160
# this is 161
# this is 162
# this is 163
# this is 164
# this is 165
# this is 166
# this is 167
# this is 168
# this is 169
# this is 170
# this is 171
# this is 172
# this is 173
# this is 174
# this is 175
# this is 176
# this is 177
# this is 178
# this is 179
# this is 180
# this is 181
# this is 182
# this is 183
# this is 184
# this is 185
# this is 186
# this is 187
# this is 188
# this is 189
# this is 190
# this is 191
# this is 192
# this is 193
# this is 194
# this is 195
# this is 196
# this is 197
# this is 198
# this is 199
# this is 200
# this is 201
# this is 202
# this is 203
# this is 204
# this is 205
# this is 206
# this is 207
# this is 208
# this is 209
# this is 210
# this is 211
# this is 212
# this is 213
# this is 214
# this is 215
# this is 216
# this is 217
# this is 218
# this is 219
# this is 220
# this is 221
# this is 222
# this is 223
# this is 224
# this is 225
# this is 226
# this is 227
# this is 228
# this is 229
# this is 230
# this is 231
# this is 232
# this is 233
# this is 234
# this is 235
# this is 236
# this is 237
# this is 238
# this is 239
# this is 240
# this is 241
# this is 242
# this is 243
# this is 244
# this is 245
# this is 246
# this is 247
# this is 248
# this is 249
# this is 250
# this is 251
# this is 252
# this is 253
# this is 254
# this is 255
# this is 256
# this is 257
# this is 258
# this is 259
# this is 260
# this is 261
# this is 262
# this is 263
# this is 264
# this is 265
# this is 266
# this is 267
# this is 268
# this is 269
# this is 270
# this is 271
# this is 272
# this is 273
# this is 274
# this is 275
# this is 276
# this is 277
# this is 278
# this is 279
# this is 280
# this is 281
# this is 282
# this is 283
# this is 284
# this is 285
# this is 286
# this is 287
# this is 288
# this is 289
# this is 290
# this is 291
# this is 292
# this is 293
# this is 294
# this is 295
# this is 296
# this is 297
# this is 298
# this is 299
# this is 300
# this is 301
# this is 302
# this is 303
# this is 304
# this is 305
# this is 306
# this is 307
# this is 308
# this is 309
# this is 310
# this is 311
# this is 312
# this is 313
# this is 314
# this is 315
# this is 316
# this is 317
# this is 318
# this is 319
# this is 320
# this is 321
# this is 322
# this is 323
# this is 324
# this is 325
# this is 326
# this is 327
# this is 328
# this is 329
# this is 330
# this is 331
# this is 332
# this is 333
# this is 334
# this is 335
# this is 336
# this is 337
# this is 338
# this is 339
# this is 340
# this is 341
# this is 342
# this is 343
# this is 344
# this is 345
# this is 346
# this is 347
# this is 348
# this is 349
# this is 350
# this is 351
# this is 352
# this is 353
# this is 354
# this is 355
# this is 356
# this is 357
# this is 358
# this is 359
# this is 360
# this is 361
# this is 362
# this is 363
# this is 364
# this is 365
# this is 366
# this is 367
# this is 368
# this is 369
# this is 370
# this is 371
# this is 372
# this is 373
# this is 374
# this is 375
# this is 376
# this is 377
# this is 378
# this is 379
# this is 380
# this is 381
# this is 382
# this is 383
# this is 384
# this is 385
# this is 386
# this is 387
# this is 388
# this is 389
# this is 390
# this is 391
# this is 392
# this is 393
# this is 394
# this is 395
# this is 396
# this is 397
# this is 398
# this is 399
# this is 400
# this is 401
# this is 402
# this is 403
# this is 404
# this is 405
# this is 406
# this is 407
# this is 408
# this is 409
# this is 410
# this is 411
# this is 412
# this is 413
# this is 414
# this is 415
# this is 416
# this is 417
# this is 418
# this is 419
# this is 420
# this is 421
# this is 422
# this is 423
# this is 424
# this is 425
# this is 426
# this is 427
# this is 428
# this is 429
# this is 430
# this is 431
# this is 432
# this is 433
# this is 434
# this is 435
# this is 436
# this is 437
# this is 438
# this is 439
# this is 440
# this is 441
# this is 442
# this is 443
# this is 444
# this is 445
# this is 446
# this is 447
# this is 448
# this is 449
# this is 450
# this is 451
# this is 452
# this is 453
# this is 454
# this is 455
# this is 456
# this is 457
# this is 458
# this is 459
# this is 460
# this is 461
# this is 462
# this is 463
# this is 464
# this is 465
# this is 466
# this is 467
# this is 468
# this is 469
# this is 470
# this is 471
# this is 472
# this is 473
# this is 474
# this is 475
# this is 476
# this is 477
# this is 478
# this is 479
# this is 480
# this is 481
# this is 482
# this is 483
# this is 484
# this is 485
# this is 486
# this is 487
# this is 488
# this is 489
# this is 490
# this is 491
# this is 492
# this is 493
# this is 494
# this is 495
# this is 496
# this is 497
# this is 498
# this is 499
# this is 500
# this is 501
# this is 502
# this is 503
# this is 504
# this is 505
# this is 506
# this is 507
# this is 508
# this is 509
# this is 510
# this is 511
# this is 512
# this is 513
# this is 514
# this is 515
# this is 516
# this is 517
# this is 518
# this is 519
# this is 520
# this is 521
# this is 522
# this is 523
# this is 524
# this is 525
# this is 526
# this is 527
# this is 528
# this is 529
# this is 530
# this is 531
# this is 532
# this is 533
# this is 534
# this is 535
# this is 536
# this is 537
# this is 538
# this is 539
# this is 540
# this is 541
# this is 542
# this is 543
# this is 544
# this is 545
# this is 546
# this is 547
# this is 548
# this is 549
# this is 550
# this is 551
# this is 552
# this is 553
# this is 554
# this is 555
# this is 556
# this is 557
# this is 558
# this is 559
# this is 560
# this is 561
# this is 562
# this is 563
# this is 564
# this is 565
# this is 566
# this is 567
# this is 568
# this is 569
# this is 570
# this is 571
# this is 572
# this is 573
# this is 574
# this is 575
# this is 576
# this is 577
# this is 578
# this is 579
# this is 580
# this is 581
# this is 582
# this is 583
# this is 584
# this is 585
# this is 586
# this is 587
# this is 588
# this is 589
# this is 590
# this is 591
# this is 592
# this is 593
# this is 594
# this is 595
# this is 596
# this is 597
# this is 598
# this is 599
# this is 600
# this is 601
# this is 602
# this is 603
# this is 604
# this is 605
# this is 606
# this is 607
# this is 608
# this is 609
# this is 610
# this is 611
# this is 612
# this is 613
# this is 614
# this is 615
# this is 616
# this is 617
# this is 618
# this is 619
# this is 620
# this is 621
# this is 622
# this is 623
# this is 624
# this is 625
# this is 626
# this is 627
# this is 628
# this is 629
# this is 630
# this is 631
# this is 632
# this is 633
# this is 634
# this is 635
# this is 636
# this is 637
# this is 638
# this is 639
# this is 640
# this is 641
# this is 642
# this is 643
# this is 644
# this is 645
# this is 646
# this is 647
# this is 648
# this is 649
# this is 650
# this is 651
# this is 652
# this is 653
# this is 654
# this is 655
# this is 656
# this is 657
# this is 658
# this is 659
# this is 660
# this is 661
# this is 662
# this is 663
# this is 664
# this is 665
# this is 666
# this is 667
# this is 668
# this is 669
# this is 670
# this is 671
# this is 672
# this is 673
# this is 674
# this is 675
# this is 676
# this is 677
# this is 678
# this is 679
# this is 680
# this is 681
# this is 682
# this is 683
# this is 684
# this is 685
# this is 686
# this is 687
# this is 688
# this is 689
# this is 690
# this is 691
# this is 692
# this is 693
# this is 694
# this is 695
# this is 696
# this is 697
# this is 698
# this is 699
# this is 700
# this is 701
# this is 702
# this is 703
# this is 704
# this is 705
# this is 706
# this is 707
# this is 708
# this is 709
# this is 710
# this is 711
# this is 712
# this is 713
# this is 714
# this is 715
# this is 716
# this is 717
# this is 718
# this is 719
# this is 720
# this is 721
# this is 722
# this is 723
# this is 724
# this is 725
# this is 726
# this is 727
# this is 728
# this is 729
# this is 730
# this is 731
# this is 732
# this is 733
# this is 734
# this is 735
# this is 736
# this is 737
# this is 738
# this is 739
# this is 740
# this is 741
# this is 742
# this is 743
# this is 744
# this is 745
# this is 746
# this is 747
# this is 748
# this is 749
# this is 750
# this is 751
# this is 752
# this is 753
# this is 754
# this is 755
# this is 756
# this is 757
# this is 758
# this is 759
# this is 760
# this is 761
# this is 762
# this is 763
# this is 764
# this is 765
# this is 766
# this is 767
# this is 768
# this is 769
# this is 770
# this is 771
# this is 772
# this is 773
# this is 774
# this is 775
# this is 776
# this is 777
# this is 778
# this is 779
# this is 780
# this is 781
# this is 782
# this is 783
# this is 784
# this is 785
# this is 786
# this is 787
# this is 788
# this is 789
# this is 790
# this is 791
# this is 792
# this is 793
# this is 794
# this is 795
# this is 796
# this is 797
# this is 798
# this is 799
# this is 800
# this is 801
# this is 802
# this is 803
# this is 804
# this is 805
# this is 806
# this is 807
# this is 808
# this is 809
# this is 810
# this is 811
# this is 812
# this is 813
# this is 814
# this is 815
# this is 816
# this is 817
# this is 818
# this is 819
# this is 820
# this is 821
# this is 822
# this is 823
# this is 824
# this is 825
# this is 826
# this is 827
# this is 828
# this is 829
# this is 830
# this is 831
# this is 832
# this is 833
# this is 834
# this is 835
# this is 836
# this is 837
# this is 838
# this is 839
# this is 840
# this is 841
# this is 842
# this is 843
# this is 844
# this is 845
# this is 846
# this is 847
# this is 848
# this is 849
# this is 850
# this is 851
# this is 852
# this is 853
# this is 854
# this is 855
# this is 856
# this is 857
# this is 858
# this is 859
# this is 860
# this is 861
# this is 862
# this is 863
# this is 864
# this is 865
# this is 866
# this is 867
# this is 868
# this is 869
# this is 870
# this is 871
# this is 872
# this is 873
# this is 874
# this is 875
# this is 876
# this is 877
# this is 878
# this is 879
# this is 880
# this is 881
# this is 882
# this is 883
# this is 884
# this is 885
# this is 886
# this is 887
# this is 888
# this is 889
# this is 890
# this is 891
# this is 892
# this is 893
# this is 894
# this is 895
# this is 896
# this is 897
# this is 898
# this is 899
# this is 900
# this is 901
# this is 902
# this is 903
# this is 904
# this is 905
# this is 906
# this is 907
# this is 908
# this is 909
# this is 910
# this is 911
# this is 912
# this is 913
# this is 914
# this is 915
# this is 916
# this is 917
# this is 918
# this is 919
# this is 920
# this is 921
# this is 922
# this is 923
# this is 924
# this is 925
# this is 926
# this is 927
# this is 928
# this is 929
# this is 930
# this is 931
# this is 932
# this is 933
# this is 934
# this is 935
# this is 936
# this is 937
# this is 938
# this is 939
# this is 940
# this is 941
# this is 942
# this is 943
# this is 944
# this is 945
# this is 946
# this is 947
# this is 948
# this is 949
# this is 950
# this is 951
# this is 952
# this is 953
# this is 954
# this is 955
# this is 956
# this is 957
# this is 958
# this is 959
# this is 960
# this is 961
# this is 962
# this is 963
# this is 964
# this is 965
# this is 966
# this is 967
# this is 968
# this is 969
# this is 970
# this is 971
# this is 972
# this is 973
# this is 974
# this is 975
# this is 976
# this is 977
# this is 978
# this is 979
# this is 980
# this is 981
# this is 982
# this is 983
# this is 984
# this is 985
# this is 986
# this is 987
# this is 988
# this is 989
# this is 990
# this is 991
# this is 992
# this is 993
# this is 994
# this is 995
# this is 996
# this is 997
# this is 998
# this is 999
# this is 1000
# this is 1001
# this is 1002
# this is 1003
# this is 1004
# this is 1005
# this is 1006
# this is 1007
# this is 1008
# this is 1009
# this is 1010
# this is 1011
# this is 1012
# this is 1013
# this is 1014
# this is 1015
# this is 1016
# this is 1017
# this is 1018
# this is 1019
# this is 1020
# this is 1021
# this is 1022
# this is 1023
# this is 1024
# this is 1025
# this is 1026
# this is 1027
# this is 1028
# this is 1029
# this is 1030
# this is 1031
# this is 1032
# this is 1033
# this is 1034
# this is 1035
# this is 1036
# this is 1037
# this is 1038
# this is 1039
# this is 1040
# this is 1041
# this is 1042
# this is 1043
# this is 1044
# this is 1045
# this is 1046
# this is 1047
# this is 1048
# this is 1049
# this is 1050
# this is 1051
# this is 1052
# this is 1053
# this is 1054
# this is 1055
# this is 1056
# this is 1057
# this is 1058
# this is 1059
# this is 1060
# this is 1061
# this is 1062
# this is 1063
# this is 1064
# this is 1065
# this is 1066
# this is 1067
# this is 1068
# this is 1069
# this is 1070
# this is 1071
# this is 1072
# this is 1073
# this is 1074
# this is 1075
# this is 1076
# this is 1077
# this is 1078
# this is 1079
# this is 1080
# this is 1081
# this is 1082
# this is 1083
# this is 1084
# this is 1085
# this is 1086
# this is 1087
# this is 1088
# this is 1089
# this is 1090
# this is 1091
# this is 1092
# this is 1093
# this is 1094
# this is 1095
# this is 1096
# this is 1097
# this is 1098
# this is 1099
# this is 1100
# this is 1101
# this is 1102
# this is 1103
# this is 1104
# this is 1105
# this is 1106
# this is 1107
# this is 1108
# this is 1109
# this is 1110
# this is 1111
# this is 1112
# this is 1113
# this is 1114
# this is 1115
# this is 1116
# this is 1117
# this is 1118
# this is 1119
# this is 1120
# this is 1121
# this is 1122
# this is 1123
# this is 1124
# this is 1125
# this is 1126
# this is 1127
# this is 1128
# this is 1129
# this is 1130
# this is 1131
# this is 1132
# this is 1133
# this is 1134
# this is 1135
# this is 1136
# this is 1137
# this is 1138
# this is 1139
# this is 1140
# this is 1141
# this is 1142
# this is 1143
# this is 1144
# this is 1145
# this is 1146
# this is 1147
# this is 1148
# this is 1149
# this is 1150
# this is 1151
# this is 1152
# this is 1153
# this is 1154
# this is 1155
# this is 1156
# this is 1157
# this is 1158
# this is 1159
# this is 1160
# this is 1161
# this is 1162
# this is 1163
# this is 1164
# this is 1165
# this is 1166
# this is 1167
# this is 1168
# this is 1169
# this is 1170
# this is 1171
# this is 1172
# this is 1173
# this is 1174
# this is 1175
# this is 1176
# this is 1177
# this is 1178
# this is 1179
# this is 1180
# this is 1181
# this is 1182
# this is 1183
# this is 1184
# this is 1185
# this is 1186
# this is 1187
# this is 1188
# this is 1189
# this is 1190
# this is 1191
# this is 1192
# this is 1193
# this is 1194
# this is 1195
# this is 1196
# this is 1197
# this is 1198
# this is 1199
# this is 1200
# this is 1201
# this is 1202
# this is 1203
# this is 1204
# this is 1205
# this is 1206
# this is 1207
# this is 1208
# this is 1209
# this is 1210
# this is 1211
# this is 1212
# this is 1213
# this is 1214
# this is 1215
# this is 1216
# this is 1217
# this is 1218
# this is 1219
# this is 1220
# this is 1221
# this is 1222
# this is 1223
# this is 1224
# this is 1225
# this is 1226
# this is 1227
# this is 1228
# this is 1229
# this is 1230
# this is 1231
# this is 1232
# this is 1233
# this is 1234
# this is 1235
# this is 1236
# this is 1237
# this is 1238
# this is 1239
# this is 1240
# this is 1241
# this is 1242
# this is 1243
# this is 1244
# this is 1245
# this is 1246
# this is 1247
# this is 1248
# this is 1249
# this is 1250
# this is 1251
# this is 1252
# this is 1253
# this is 1254
# this is 1255
# this is 1256
# this is 1257
# this is 1258
# this is 1259
# this is 1260
# this is 1261
# this is 1262
# this is 1263
# this is 1264
# this is 1265
# this is 1266
# this is 1267
# this is 1268
# this is 1269
# this is 1270
# this is 1271
# this is 1272
# this is 1273
# this is 1274
# this is 1275
# this is 1276
# this is 1277
# this is 1278
# this is 1279
# this is 1280
# this is 1281
# this is 1282
# this is 1283
# this is 1284
# this is 1285
# this is 1286
# this is 1287
# this is 1288
# this is 1289
# this is 1290
# this is 1291
# this is 1292
# this is 1293
# this is 1294
# this is 1295
# this is 1296
# this is 1297
# this is 1298
# this is 1299
# this is 1300
# this is 1301
# this is 1302
# this is 1303
# this is 1304
# this is 1305
# this is 1306
# this is 1307
# this is 1308
# this is 1309
# this is 1310
# this is 1311
# this is 1312
# this is 1313
# this is 1314
# this is 1315
# this is 1316
# this is 1317
# this is 1318
# this is 1319
# this is 1320
# this is 1321
# this is 1322
# this is 1323
# this is 1324
# this is 1325
# this is 1326
# this is 1327
# this is 1328
# this is 1329
# this is 1330
# this is 1331
# this is 1332
# this is 1333
# this is 1334
# this is 1335
# this is 1336
# this is 1337
# this is 1338
# this is 1339
# this is 1340
# this is 1341
# this is 1342
# this is 1343
# this is 1344
# this is 1345
# this is 1346
# this is 1347
# this is 1348
# this is 1349
# this is 1350
# this is 1351
# this is 1352
# this is 1353
# this is 1354
# this is 1355
# this is 1356
# this is 1357
# this is 1358
# this is 1359
# this is 1360
# this is 1361
# this is 1362
# this is 1363
# this is 1364
# this is 1365
# this is 1366
# this is 1367
# this is 1368
# this is 1369
# this is 1370
# this is 1371
# this is 1372
# this is 1373
# this is 1374
# this is 1375
# this is 1376
# this is 1377
# this is 1378
# this is 1379
# this is 1380
# this is 1381
# this is 1382
# this is 1383
# this is 1384
# this is 1385
# this is 1386
# this is 1387
# this is 1388
# this is 1389
# this is 1390
# this is 1391
# this is 1392
# this is 1393
# this is 1394
# this is 1395
# this is 1396
# this is 1397
# this is 1398
# this is 1399
# this is 1400
# this is 1401
# this is 1402
# this is 1403
# this is 1404
# this is 1405
# this is 1406
# this is 1407
# this is 1408
# this is 1409
# this is 1410
# this is 1411
# this is 1412
# this is 1413
# this is 1414
# this is 1415
# this is 1416
# this is 1417
# this is 1418
# this is 1419
# this is 1420
# this is 1421
# this is 1422
# this is 1423
# this is 1424
# this is 1425
# this is 1426
# this is 1427
# this is 1428
# this is 1429
# this is 1430
# this is 1431
# this is 1432
# this is 1433
# this is 1434
# this is 1435
# this is 1436
# this is 1437
# this is 1438
# this is 1439
# this is 1440
# this is 1441
# this is 1442
# this is 1443
# this is 1444
# this is 1445
# this is 1446
# this is 1447
# this is 1448
# this is 1449
# this is 1450
# this is 1451
# this is 1452
# this is 1453
# this is 1454
# this is 1455
# this is 1456
# this is 1457
# this is 1458
# this is 1459
# this is 1460
# this is 1461
# this is 1462
# this is 1463
# this is 1464
# this is 1465
# this is 1466
# this is 1467
# this is 1468
# this is 1469
# this is 1470
# this is 1471
# this is 1472
# this is 1473
# this is 1474
# this is 1475
# this is 1476
# this is 1477
# this is 1478
# this is 1479
# this is 1480
# this is 1481
# this is 1482
# this is 1483
# this is 1484
# this is 1485
# this is 1486
# this is 1487
# this is 1488
# this is 1489
# this is 1490
# this is 1491
# this is 1492
# this is 1493
# this is 1494
# this is 1495
# this is 1496
# this is 1497
# this is 1498
# this is 1499
# this is 1500
# this is 1501
# this is 1502
# this is 1503
# this is 1504
# this is 1505
# this is 1506
# this is 1507
# this is 1508
# this is 1509
# this is 1510
# this is 1511
# this is 1512
# this is 1513
# this is 1514
# this is 1515
# this is 1516
# this is 1517
# this is 1518
# this is 1519
# this is 1520
# this is 1521
# this is 1522
# this is 1523
# this is 1524
# this is 1525
# this is 1526
# this is 1527
# this is 1528
# this is 1529
# this is 1530
# this is 1531
# this is 1532
# this is 1533
# this is 1534
# this is 1535
# this is 1536
# this is 1537
# this is 1538
# this is 1539
# this is 1540
# this is 1541
# this is 1542
# this is 1543
# this is 1544
# this is 1545
# this is 1546
# this is 1547
# this is 1548
# this is 1549
# this is 1550
# this is 1551
# this is 1552
# this is 1553
# this is 1554
# this is 1555
# this is 1556
# this is 1557
# this is 1558
# this is 1559
# this is 1560
# this is 1561
# this is 1562
# this is 1563
# this is 1564
# this is 1565
# this is 1566
# this is 1567
# this is 1568
# this is 1569
# this is 1570
# this is 1571
# this is 1572
# this is 1573
# this is 1574
# this is 1575
# this is 1576
# this is 1577
# this is 1578
# this is 1579
# this is 1580
# this is 1581
# this is 1582
# this is 1583
# this is 1584
# this is 1585
# this is 1586
# this is 1587
# this is 1588
# this is 1589
# this is 1590
# this is 1591
# this is 1592
# this is 1593
# this is 1594
# this is 1595
# this is 1596
# this is 1597
# this is 1598
# this is 1599
# this is 1600
# this is 1601
# this is 1602
# this is 1603
# this is 1604
# this is 1605
# this is 1606
# this is 1607
# this is 1608
# this is 1609
# this is 1610
# this is 1611
# this is 1612
# this is 1613
# this is 1614
# this is 1615
# this is 1616
# this is 1617
# this is 1618
# this is 1619
# this is 1620
# this is 1621
# this is 1622
# this is 1623
# this is 1624
# this is 1625
# this is 1626
# this is 1627
# this is 1628
# this is 1629
# this is 1630
# this is 1631
# this is 1632
# this is 1633
# this is 1634
# this is 1635
# this is 1636
# this is 1637
# this is 1638
# this is 1639
# this is 1640
# this is 1641
# this is 1642
# this is 1643
# this is 1644
# this is 1645
# this is 1646
# this is 1647
# this is 1648
# this is 1649
# this is 1650
# this is 1651
# this is 1652
# this is 1653
# this is 1654
# this is 1655
# this is 1656
# this is 1657
# this is 1658
# this is 1659
# this is 1660
# this is 1661
# this is 1662
# this is 1663
# this is 1664
# this is 1665
# this is 1666
# this is 1667
# this is 1668
# this is 1669
# this is 1670
# this is 1671
# this is 1672
# this is 1673
# this is 1674
# this is 1675
# this is 1676
# this is 1677
# this is 1678
# this is 1679
# this is 1680
# this is 1681
# this is 1682
# this is 1683
# this is 1684
# this is 1685
# this is 1686
# this is 1687
# this is 1688
# this is 1689
# this is 1690
# this is 1691
# this is 1692
# this is 1693
# this is 1694
# this is 1695
# this is 1696
# this is 1697
# this is 1698
# this is 1699
# this is 1700
# this is 1701
# this is 1702
# this is 1703
# this is 1704
# this is 1705
# this is 1706
# this is 1707
# this is 1708
# this is 1709
# this is 1710
# this is 1711
# this is 1712
# this is 1713
# this is 1714
# this is 1715
# this is 1716
# this is 1717
# this is 1718
# this is 1719
# this is 1720
# this is 1721
# this is 1722
# this is 1723
# this is 1724
# this is 1725
# this is 1726
# this is 1727
# this is 1728
# this is 1729
# this is 1730
# this is 1731
# this is 1732
# this is 1733
# this is 1734
# this is 1735
# this is 1736
# this is 1737
# this is 1738
# this is 1739
# this is 1740
# this is 1741
# this is 1742
# this is 1743
# this is 1744
# this is 1745
# this is 1746
# this is 1747
# this is 1748
# this is 1749
# this is 1750
# this is 1751
# this is 1752
# this is 1753
# this is 1754
# this is 1755
# this is 1756
# this is 1757
# this is 1758
# this is 1759
# this is 1760
# this is 1761
# this is 1762
# this is 1763
# this is 1764
# this is 1765
# this is 1766
# this is 1767
# this is 1768
# this is 1769
# this is 1770
# this is 1771
# this is 1772
# this is 1773
# this is 1774
# this is 1775
# this is 1776
# this is 1777
# this is 1778
# this is 1779
# this is 1780
# this is 1781
# this is 1782
# this is 1783
# this is 1784
# this is 1785
# this is 1786
# this is 1787
# this is 1788
# this is 1789
# this is 1790
# this is 1791
# this is 1792
# this is 1793
# this is 1794
# this is 1795
# this is 1796
# this is 1797
# this is 1798
# this is 1799
# this is 1800
# this is 1801
# this is 1802
# this is 1803
# this is 1804
# this is 1805
# this is 1806
# this is 1807
# this is 1808
# this is 1809
# this is 1810
# this is 1811
# this is 1812
# this is 1813
# this is 1814
# this is 1815
# this is 1816
# this is 1817
# this is 1818
# this is 1819
# this is 1820
# this is 1821
# this is 1822
# this is 1823
# this is 1824
# this is 1825
# this is 1826
# this is 1827
# this is 1828
# this is 1829
# this is 1830
# this is 1831
# this is 1832
# this is 1833
# this is 1834
# this is 1835
# this is 1836
# this is 1837
# this is 1838
# this is 1839
# this is 1840
# this is 1841
# this is 1842
# this is 1843
# this is 1844
# this is 1845
# this is 1846
# this is 1847
# this is 1848
# this is 1849
# this is 1850
# this is 1851
# this is 1852
# this is 1853
# this is 1854
# this is 1855
# this is 1856
# this is 1857
# this is 1858
# this is 1859
# this is 1860
# this is 1861
# this is 1862
# this is 1863
# this is 1864
# this is 1865
# this is 1866
# this is 1867
# this is 1868
# this is 1869
# this is 1870
# this is 1871
# this is 1872
# this is 1873
# this is 1874
# this is 1875
# this is 1876
# this is 1877
# this is 1878
# this is 1879
# this is 1880
# this is 1881
# this is 1882
# this is 1883
# this is 1884
# this is 1885
# this is 1886
# this is 1887
# this is 1888
# this is 1889
# this is 1890
# this is 1891
# this is 1892
# this is 1893
# this is 1894
# this is 1895
# this is 1896
# this is 1897
# this is 1898
# this is 1899
# this is 1900
# this is 1901
# this is 1902
# this is 1903
# this is 1904
# this is 1905
# this is 1906
# this is 1907
# this is 1908
# this is 1909
# this is 1910
# this is 1911
# this is 1912
# this is 1913
# this is 1914
# this is 1915
# this is 1916
# this is 1917
# this is 1918
# this is 1919
# this is 1920
# this is 1921
# this is 1922
# this is 1923
# this is 1924
# this is 1925
# this is 1926
# this is 1927
# this is 1928
# this is 1929
# this is 1930
# this is 1931
# this is 1932
# this is 1933
# this is 1934
# this is 1935
# this is 1936
# this is 1937
# this is 1938
# this is 1939
# this is 1940
# this is 1941
# this is 1942
# this is 1943
# this is 1944
# this is 1945
# this is 1946
# this is 1947
# this is 1948
# this is 1949
# this is 1950
# this is 1951
# this is 1952
# this is 1953
# this is 1954
# this is 1955
# this is 1956
# this is 1957
# this is 1958
# this is 1959
# this is 1960
# this is 1961
# this is 1962
# this is 1963
# this is 1964
# this is 1965
# this is 1966
# this is 1967
# this is 1968
# this is 1969
# this is 1970
# this is 1971
# this is 1972
# this is 1973
# this is 1974
# this is 1975
# this is 1976
# this is 1977
# this is 1978
# this is 1979
# this is 1980
# this is 1981
# this is 1982
# this is 1983
# this is 1984
# this is 1985
# this is 1986
# this is 1987
# this is 1988
# this is 1989
# this is 1990
# this is 1991
# this is 1992
# this is 1993
# this is 1994
# this is 1995
# this is 1996
# this is 1997
# this is 1998
# this is 1999
# this is 2000
# this is 2001
# this is 2002
# this is 2003
# this is 2004
# this is 2005
# this is 2006
# this is 2007
# this is 2008
# this is 2009
# this is 2010
# this is 2011
# this is 2012
# this is 2013
# this is 2014
# this is 2015
# this is 2016
# this is 2017
# this is 2018
# this is 2019
# this is 2020
# this is 2021
# this is 2022
# this is 2023
# this is 2024
# this is 2025
# this is 2026
# this is 2027
# this is 2028
# this is 2029
# this is 2030
# this is 2031
# this is 2032
# this is 2033
# this is 2034
# this is 2035
# this is 2036
# this is 2037
# this is 2038
# this is 2039
# this is 2040
# this is 2041
# this is 2042
# this is 2043
# this is 2044
# this is 2045
# this is 2046
# this is 2047
# this is 2048
# this is 2049
# this is 2050
# this is 2051
# this is 2052
# this is 2053
# this is 2054
# this is 2055
# this is 2056
# this is 2057
# this is 2058
# this is 2059
# this is 2060
# this is 2061
# this is 2062
# this is 2063
# this is 2064
# this is 2065
# this is 2066
# this is 2067
# this is 2068
# this is 2069
# this is 2070
# this is 2071
# this is 2072
# this is 2073
# this is 2074
# this is 2075
# this is 2076
# this is 2077
# this is 2078
# this is 2079
# this is 2080
# this is 2081
# this is 2082
# this is 2083
# this is 2084
# this is 2085
# this is 2086
# this is 2087
# this is 2088
# this is 2089
# this is 2090
# this is 2091
# this is 2092
# this is 2093
# this is 2094
# this is 2095
# this is 2096
# this is 2097
# this is 2098
# this is 2099
# this is 2100
# this is 2101
# this is 2102
# this is 2103
# this is 2104
# this is 2105
# this is 2106
# this is 2107
# this is 2108
# this is 2109
# this is 2110
# this is 2111
# this is 2112
# this is 2113
# this is 2114
# this is 2115
# this is 2116
# this is 2117
# this is 2118
# this is 2119
# this is 2120
# this is 2121
# this is 2122
# this is 2123
# this is 2124
# this is 2125
# this is 2126
# this is 2127
# this is 2128
# this is 2129
# this is 2130
# this is 2131
# this is 2132
# this is 2133
# this is 2134
# this is 2135
# this is 2136
# this is 2137
# this is 2138
# this is 2139
# this is 2140
# this is 2141
# this is 2142
# this is 2143
# this is 2144
# this is 2145
# this is 2146
# this is 2147
# this is 2148
# this is 2149
# this is 2150
# this is 2151
# this is 2152
# this is 2153
# this is 2154
# this is 2155
# this is 2156
# this is 2157
# this is 2158
# this is 2159
# this is 2160
# this is 2161
# this is 2162
# this is 2163
# this is 2164
# this is 2165
# this is 2166
# this is 2167
# this is 2168
# this is 2169
# this is 2170
# this is 2171
# this is 2172
# this is 2173
# this is 2174
# this is 2175
# this is 2176
# this is 2177
# this is 2178
# this is 2179
# this is 2180
# this is 2181
# this is 2182
# this is 2183
# this is 2184
# this is 2185
# this is 2186
# this is 2187
# this is 2188
# this is 2189
# this is 2190
# this is 2191
# this is 2192
# this is 2193
# this is 2194
# this is 2195
# this is 2196
# this is 2197
# this is 2198
# this is 2199
# this is 2200
# this is 2201
# this is 2202
# this is 2203
# this is 2204
# this is 2205
# this is 2206
# this is 2207
# this is 2208
# this is 2209
# this is 2210
# this is 2211
# this is 2212
# this is 2213
# this is 2214
# this is 2215
# this is 2216
# this is 2217
# this is 2218
# this is 2219
# this is 2220
# this is 2221
# this is 2222
# this is 2223
# this is 2224
# this is 2225
# this is 2226
# this is 2227
# this is 2228
# this is 2229
# this is 2230
# this is 2231
# this is 2232
# this is 2233
# this is 2234
# this is 2235
# this is 2236
# this is 2237
# this is 2238
# this is 2239
# this is 2240
# this is 2241
# this is 2242
# this is 2243
# this is 2244
# this is 2245
# this is 2246
# this is 2247
# this is 2248
# this is 2249
# this is 2250
# this is 2251
# this is 2252
# this is 2253
# this is 2254
# this is 2255
# this is 2256
# this is 2257
# this is 2258
# this is 2259
# this is 2260
# this is 2261
# this is 2262
# this is 2263
# this is 2264
# this is 2265
# this is 2266
# this is 2267
# this is 2268
# this is 2269
# this is 2270
# this is 2271
# this is 2272
# this is 2273
# this is 2274
# this is 2275
# this is 2276
# this is 2277
# this is 2278
# this is 2279
# this is 2280
# this is 2281
# this is 2282
# this is 2283
# this is 2284
# this is 2285
# this is 2286
# this is 2287
# this is 2288
# this is 2289
# this is 2290
# this is 2291
# this is 2292
# this is 2293
# this is 2294
# this is 2295
# this is 2296
# this is 2297
# this is 2298
# this is 2299
# this is 2300
# this is 2301
# this is 2302
# this is 2303
# this is 2304
# this is 2305
# this is 2306
# this is 2307
# this is 2308
# this is 2309
# this is 2310
# this is 2311
# this is 2312
# this is 2313
# this is 2314
# this is 2315
# this is 2316
# this is 2317
# this is 2318
# this is 2319
# this is 2320
# this is 2321
# this is 2322
# this is 2323
# this is 2324
# this is 2325
# this is 2326
# this is 2327
# this is 2328
# this is 2329
# this is 2330
# this is 2331
# this is 2332
# this is 2333
# this is 2334
# this is 2335
# this is 2336
# this is 2337
# this is 2338
# this is 2339
# this is 2340
# this is 2341
# this is 2342
# this is 2343
# this is 2344
# this is 2345
# this is 2346
# this is 2347
# this is 2348
# this is 2349
# this is 2350
# this is 2351
# this is 2352
# this is 2353
# this is 2354
# this is 2355
# this is 2356
# this is 2357
# this is 2358
# this is 2359
# this is 2360
# this is 2361
# this is 2362
# this is 2363
# this is 2364
# this is 2365
# this is 2366
# this is 2367
# this is 2368
# this is 2369
# this is 2370
# this is 2371
# this is 2372
# this is 2373
# this is 2374
# this is 2375
# this is 2376
# this is 2377
# this is 2378
# this is 2379
# this is 2380
# this is 2381
# this is 2382
# this is 2383
# this is 2384
# this is 2385
# this is 2386
# this is 2387
# this is 2388
# this is 2389
# this is 2390
# this is 2391
# this is 2392
# this is 2393
# this is 2394
# this is 2395
# this is 2396
# this is 2397
# this is 2398
# this is 2399
# this is 2400
# this is 2401
# this is 2402
# this is 2403
# this is 2404
# this is 2405
# this is 2406
# this is 2407
# this is 2408
# this is 2409
# this is 2410
# this is 2411
# this is 2412
# this is 2413
# this is 2414
# this is 2415
# this is 2416
# this is 2417
# this is 2418
# this is 2419
# this is 2420
# this is 2421
# this is 2422
# this is 2423
# this is 2424
# this is 2425
# this is 2426
# this is 2427
# this is 2428
# this is 2429
# this is 2430
# this is 2431
# this is 2432
# this is 2433
# this is 2434
# this is 2435
# this is 2436
# this is 2437
# this is 2438
# this is 2439
# this is 2440
# this is 2441
# this is 2442
# this is 2443
# this is 2444
# this is 2445
# this is 2446
# this is 2447
# this is 2448
# this is 2449
# this is 2450
# this is 2451
# this is 2452
# this is 2453
# this is 2454
# this is 2455
# this is 2456
# this is 2457
# this is 2458
# this is 2459
# this is 2460
# this is 2461
# this is 2462
# this is 2463
# this is 2464
# this is 2465
# this is 2466
# this is 2467
# this is 2468
# this is 2469
# this is 2470
# this is 2471
# this is 2472
# this is 2473
# this is 2474
# this is 2475
# this is 2476
# this is 2477
# this is 2478
# this is 2479
# this is 2480
# this is 2481
# this is 2482
# this is 2483
# this is 2484
# this is 2485
# this is 2486
# this is 2487
# this is 2488
# this is 2489
# this is 2490
# this is 2491
# this is 2492
# this is 2493
# this is 2494
# this is 2495
# this is 2496
# this is 2497
# this is 2498
# this is 2499
# this is 2500
# this is 2501
# this is 2502
# this is 2503
# this is 2504
# this is 2505
# this is 2506
# this is 2507
# this is 2508
# this is 2509
# this is 2510
# this is 2511
# this is 2512
# this is 2513
# this is 2514
# this is 2515
# this is 2516
# this is 2517
# this is 2518
# this is 2519
# this is 2520
# this is 2521
# this is 2522
# this is 2523
# this is 2524
# this is 2525
# this is 2526
# this is 2527
# this is 2528
# this is 2529
# this is 2530
# this is 2531
# this is 2532
# this is 2533
# this is 2534
# this is 2535
# this is 2536
# this is 2537
# this is 2538
# this is 2539
# this is 2540
# this is 2541
# this is 2542
# this is 2543
# this is 2544
# this is 2545
# this is 2546
# this is 2547
# this is 2548
# this is 2549
# this is 2550
# this is 2551
# this is 2552
# this is 2553
# this is 2554
# this is 2555
# this is 2556
# this is 2557
# this is 2558
# this is 2559
# this is 2560
# this is 2561
# this is 2562
# this is 2563
# this is 2564
# this is 2565
# this is 2566
# this is 2567
# this is 2568
# this is 2569
# this is 2570
# this is 2571
# this is 2572
# this is 2573
# this is 2574
# this is 2575
# this is 2576
# this is 2577
# this is 2578
# this is 2579
# this is 2580
# this is 2581
# this is 2582
# this is 2583
# this is 2584
# this is 2585
# this is 2586
# this is 2587
# this is 2588
# this is 2589
# this is 2590
# this is 2591
# this is 2592
# this is 2593
# this is 2594
# this is 2595
# this is 2596
# this is 2597
# this is 2598
# this is 2599
# this is 2600
# this is 2601
# this is 2602
# this is 2603
# this is 2604
# this is 2605
# this is 2606
# this is 2607
# this is 2608
# this is 2609
# this is 2610
# this is 2611
# this is 2612
# this is 2613
# this is 2614
# this is 2615
# this is 2616
# this is 2617
# this is 2618
# this is 2619
# this is 2620
# this is 2621
# this is 2622
# this is 2623
# this is 2624
# this is 2625
# this is 2626
# this is 2627
# this is 2628
# this is 2629
# this is 2630
# this is 2631
# this is 2632
# this is 2633
# this is 2634
# this is 2635
# this is 2636
# this is 2637
# this is 2638
# this is 2639
# this is 2640
# this is 2641
# this is 2642
# this is 2643
# this is 2644
# this is 2645
# this is 2646
# this is 2647
# this is 2648
# this is 2649
# this is 2650
# this is 2651
# this is 2652
# this is 2653
# this is 2654
# this is 2655
# this is 2656
# this is 2657
# this is 2658
# this is 2659
# this is 2660
# this is 2661
# this is 2662
# this is 2663
# this is 2664
# this is 2665
# this is 2666
# this is 2667
# this is 2668
# this is 2669
# this is 2670
# this is 2671
# this is 2672
# this is 2673
# this is 2674
# this is 2675
# this is 2676
# this is 2677
# this is 2678
# this is 2679
# this is 2680
# this is 2681
# this is 2682
# this is 2683
# this is 2684
# this is 2685
# this is 2686
# this is 2687
# this is 2688
# this is 2689
# this is 2690
# this is 2691
# this is 2692
# this is 2693
# this is 2694
# this is 2695
# this is 2696
# this is 2697
# this is 2698
# this is 2699
# this is 2700
# this is 2701
# this is 2702
# this is 2703
# this is 2704
# this is 2705
# this is 2706
# this is 2707
# this is 2708
# this is 2709
# this is 2710
# this is 2711
# this is 2712
# this is 2713
# this is 2714
# this is 2715
# this is 2716
# this is 2717
# this is 2718
# this is 2719
# this is 2720
# this is 2721
# this is 2722
# this is 2723
# this is 2724
# this is 2725
# this is 2726
# this is 2727
# this is 2728
# this is 2729
# this is 2730
# this is 2731
# this is 2732
# this is 2733
# this is 2734
# this is 2735
# this is 2736
# this is 2737
# this is 2738
# this is 2739
# this is 2740
# this is 2741
# this is 2742
# this is 2743
# this is 2744
# this is 2745
# this is 2746
# this is 2747
# this is 2748
# this is 2749
# this is 2750
# this is 2751
# this is 2752
# this is 2753
# this is 2754
# this is 2755
# this is 2756
# this is 2757
# this is 2758
# this is 2759
# this is 2760
# this is 2761
# this is 2762
# this is 2763
# this is 2764
# this is 2765
# this is 2766
# this is 2767
# this is 2768
# this is 2769
# this is 2770
# this is 2771
# this is 2772
# this is 2773
# this is 2774
# this is 2775
# this is 2776
# this is 2777
# this is 2778
# this is 2779
# this is 2780
# this is 2781
# this is 2782
# this is 2783
# this is 2784
# this is 2785
# this is 2786
# this is 2787
# this is 2788
# this is 2789
# this is 2790
# this is 2791
# this is 2792
# this is 2793
# this is 2794
# this is 2795
# this is 2796
# this is 2797
# this is 2798
# this is 2799
# this is 2800
# this is 2801
# this is 2802
# this is 2803
# this is 2804
# this is 2805
# this is 2806
# this is 2807
# this is 2808
# this is 2809
# this is 2810
# this is 2811
# this is 2812
# this is 2813
# this is 2814
# this is 2815
# this is 2816
# this is 2817
# this is 2818
# this is 2819
# this is 2820
# this is 2821
# this is 2822
# this is 2823
# this is 2824
# this is 2825
# this is 2826
# this is 2827
# this is 2828
# this is 2829
# this is 2830
# this is 2831
# this is 2832
# this is 2833
# this is 2834
# this is 2835
# this is 2836
# this is 2837
# this is 2838
# this is 2839
# this is 2840
# this is 2841
# this is 2842
# this is 2843
# this is 2844
# this is 2845
# this is 2846
# this is 2847
# this is 2848
# this is 2849
# this is 2850
# this is 2851
# this is 2852
# this is 2853
# this is 2854
# this is 2855
# this is 2856
# this is 2857
# this is 2858
# this is 2859
# this is 2860
# this is 2861
# this is 2862
# this is 2863
# this is 2864
# this is 2865
# this is 2866
# this is 2867
# this is 2868
# this is 2869
# this is 2870
# this is 2871
# this is 2872
# this is 2873
# this is 2874
# this is 2875
# this is 2876
# this is 2877
# this is 2878
# this is 2879
# this is 2880
# this is 2881
# this is 2882
# this is 2883
# this is 2884
# this is 2885
# this is 2886
# this is 2887
# this is 2888
# this is 2889
# this is 2890
# this is 2891
# this is 2892
# this is 2893
# this is 2894
# this is 2895
# this is 2896
# this is 2897
# this is 2898
# this is 2899
# this is 2900
# this is 2901
# this is 2902
# this is 2903
# this is 2904
# this is 2905
# this is 2906
# this is 2907
# this is 2908
# this is 2909
# this is 2910
# this is 2911
# this is 2912
# this is 2913
# this is 2914
# this is 2915
# this is 2916
# this is 2917
# this is 2918
# this is 2919
# this is 2920
# this is 2921
# this is 2922
# this is 2923
# this is 2924
# this is 2925
# this is 2926
# this is 2927
# this is 2928
# this is 2929
# this is 2930
# this is 2931
# this is 2932
# this is 2933
# this is 2934
# this is 2935
# this is 2936
# this is 2937
# this is 2938
# this is 2939
# this is 2940
# this is 2941
# this is 2942
# this is 2943
# this is 2944
# this is 2945
# this is 2946
# this is 2947
# this is 2948
# this is 2949
# this is 2950
# this is 2951
# this is 2952
# this is 2953
# this is 2954
# this is 2955
# this is 2956
# this is 2957
# this is 2958
# this is 2959
# this is 2960
# this is 2961
# this is 2962
# this is 2963
# this is 2964
# this is 2965
# this is 2966
# this is 2967
# this is 2968
# this is 2969
# this is 2970
# this is 2971
# this is 2972
# this is 2973
# this is 2974
# this is 2975
# this is 2976
# this is 2977
# this is 2978
# this is 2979
# this is 2980
# this is 2981
# this is 2982
# this is 2983
# this is 2984
# this is 2985
# this is 2986
# this is 2987
# this is 2988
# this is 2989
# this is 2990
# this is 2991
# this is 2992
# this is 2993
# this is 2994
# this is 2995
# this is 2996
# this is 2997
# this is 2998
# this is 2999
# this is 3000
# this is 3001
# this is 3002
# this is 3003
# this is 3004
# this is 3005
# this is 3006
# this is 3007
# this is 3008
# this is 3009
# this is 3010
# this is 3011
# this is 3012
# this is 3013
# this is 3014
# this is 3015
# this is 3016
# this is 3017
# this is 3018
# this is 3019
# this is 3020
# this is 3021
# this is 3022
# this is 3023
# this is 3024
# this is 3025
# this is 3026
# this is 3027
# this is 3028
# this is 3029
# this is 3030
# this is 3031
# this is 3032
# this is 3033
# this is 3034
# this is 3035
# this is 3036
# this is 3037
# this is 3038
# this is 3039
# this is 3040
# this is 3041
# this is 3042
# this is 3043
# this is 3044
# this is 3045
# this is 3046
# this is 3047
# this is 3048
# this is 3049
# this is 3050
# this is 3051
# this is 3052
# this is 3053
# this is 3054
# this is 3055
# this is 3056
# this is 3057
# this is 3058
# this is 3059
# this is 3060
# this is 3061
# this is 3062
# this is 3063
# this is 3064
# this is 3065
# this is 3066
# this is 3067
# this is 3068
# this is 3069
# this is 3070
# this is 3071
# this is 3072
# this is 3073
# this is 3074
# this is 3075
# this is 3076
# this is 3077
# this is 3078
# this is 3079
# this is 3080
# this is 3081
# this is 3082
# this is 3083
# this is 3084
# this is 3085
# this is 3086
# this is 3087
# this is 3088
# this is 3089
# this is 3090
# this is 3091
# this is 3092
# this is 3093
# this is 3094
# this is 3095
# this is 3096
# this is 3097
# this is 3098
# this is 3099
# this is 3100
# this is 3101
# this is 3102
# this is 3103
# this is 3104
# this is 3105
# this is 3106
# this is 3107
# this is 3108
# this is 3109
# this is 3110
# this is 3111
# this is 3112
# this is 3113
# this is 3114
# this is 3115
# this is 3116
# this is 3117
# this is 3118
# this is 3119
# this is 3120
# this is 3121
# this is 3122
# this is 3123
# this is 3124
# this is 3125
# this is 3126
# this is 3127
# this is 3128
# this is 3129
# this is 3130
# this is 3131
# this is 3132
# this is 3133
# this is 3134
# this is 3135
# this is 3136
# this is 3137
# this is 3138
# this is 3139
# this is 3140
# this is 3141
# this is 3142
# this is 3143
# this is 3144
# this is 3145
# this is 3146
# this is 3147
# this is 3148
# this is 3149
# this is 3150
# this is 3151
# this is 3152
# this is 3153
# this is 3154
# this is 3155
# this is 3156
# this is 3157
# this is 3158
# this is 3159
# this is 3160
# this is 3161
# this is 3162
# this is 3163
# this is 3164
# this is 3165
# this is 3166
# this is 3167
# this is 3168
# this is 3169
# this is 3170
# this is 3171
# this is 3172
# this is 3173
# this is 3174
# this is 3175
# this is 3176
# this is 3177
# this is 3178
# this is 3179
# this is 3180
# this is 3181
# this is 3182
# this is 3183
# this is 3184
# this is 3185
# this is 3186
# this is 3187
# this is 3188
# this is 3189
# this is 3190
# this is 3191
# this is 3192
# this is 3193
# this is 3194
# this is 3195
# this is 3196
# this is 3197
# this is 3198
# this is 3199
# this is 3200
# this is 3201
# this is 3202
# this is 3203
# this is 3204
# this is 3205
# this is 3206
# this is 3207
# this is 3208
# this is 3209
# this is 3210
# this is 3211
# this is 3212
# this is 3213
# this is 3214
# this is 3215
# this is 3216
# this is 3217
# this is 3218
# this is 3219
# this is 3220
# this is 3221
# this is 3222
# this is 3223
# this is 3224
# this is 3225
# this is 3226
# this is 3227
# this is 3228
# this is 3229
# this is 3230
# this is 3231
# this is 3232
# this is 3233
# this is 3234
# this is 3235
# this is 3236
# this is 3237
# this is 3238
# this is 3239
# this is 3240
# this is 3241
# this is 3242
# this is 3243
# this is 3244
# this is 3245
# this is 3246
# this is 3247
# this is 3248
# this is 3249
# this is 3250
# this is 3251
# this is 3252
# this is 3253
# this is 3254
# this is 3255
# this is 3256
# this is 3257
# this is 3258
# this is 3259
# this is 3260
# this is 3261
# this is 3262
# this is 3263
# this is 3264
# this is 3265
# this is 3266
# this is 3267
# this is 3268
# this is 3269
# this is 3270
# this is 3271
# this is 3272
# this is 3273
# this is 3274
# this is 3275
# this is 3276
# this is 3277
# this is 3278
# this is 3279
# this is 3280
# this is 3281
# this is 3282
# this is 3283
# this is 3284
# this is 3285
# this is 3286
# this is 3287
# this is 3288
# this is 3289
# this is 3290
# this is 3291
# this is 3292
# this is 3293
# this is 3294
# this is 3295
# this is 3296
# this is 3297
# this is 3298
# this is 3299
# this is 3300
# this is 3301
# this is 3302
# this is 3303
# this is 3304
# this is 3305
# this is 3306
# this is 3307
# this is 3308
# this is 3309
# this is 3310
# this is 3311
# this is 3312
# this is 3313
# this is 3314
# this is 3315
# this is 3316
# this is 3317
# this is 3318
# this is 3319
# this is 3320
# this is 3321
# this is 3322
# this is 3323
# this is 3324
# this is 3325
# this is 3326
# this is 3327
# this is 3328
# this is 3329
# this is 3330
# this is 3331
# this is 3332
# this is 3333
# this is 3334
# this is 3335
# this is 3336
# this is 3337
# this is 3338
# this is 3339
# this is 3340
# this is 3341
# this is 3342
# this is 3343
# this is 3344
# this is 3345
# this is 3346
# this is 3347
# this is 3348
# this is 3349
# this is 3350
# this is 3351
# this is 3352
# this is 3353
# this is 3354
# this is 3355
# this is 3356
# this is 3357
# this is 3358
# this is 3359
# this is 3360
# this is 3361
# this is 3362
# this is 3363
# this is 3364
# this is 3365
# this is 3366
# this is 3367
# this is 3368
# this is 3369
# this is 3370
# this is 3371
# this is 3372
# this is 3373
# this is 3374
# this is 3375
# this is 3376
# this is 3377
# this is 3378
# this is 3379
# this is 3380
# this is 3381
# this is 3382
# this is 3383
# this is 3384
# this is 3385
# this is 3386
# this is 3387
# this is 3388
# this is 3389
# this is 3390
# this is 3391
# this is 3392
# this is 3393
# this is 3394
# this is 3395
# this is 3396
# this is 3397
# this is 3398
# this is 3399
# this is 3400
# this is 3401
# this is 3402
# this is 3403
# this is 3404
# this is 3405
# this is 3406
# this is 3407
# this is 3408
# this is 3409
# this is 3410
# this is 3411
# this is 3412
# this is 3413
# this is 3414
# this is 3415
# this is 3416
# this is 3417
# this is 3418
# this is 3419
# this is 3420
# this is 3421
# this is 3422
# this is 3423
# this is 3424
# this is 3425
# this is 3426
# this is 3427
# this is 3428
# this is 3429
# this is 3430
# this is 3431
# this is 3432
# this is 3433
# this is 3434
# this is 3435
# this is 3436
# this is 3437
# this is 3438
# this is 3439
# this is 3440
# this is 3441
# this is 3442
# this is 3443
# this is 3444
# this is 3445
# this is 3446
# this is 3447
# this is 3448
# this is 3449
# this is 3450
# this is 3451
# this is 3452
# this is 3453
# this is 3454
# this is 3455
# this is 3456
# this is 3457
# this is 3458
# this is 3459
# this is 3460
# this is 3461
# this is 3462
# this is 3463
# this is 3464
# this is 3465
# this is 3466
# this is 3467
# this is 3468
# this is 3469
# this is 3470
# this is 3471
# this is 3472
# this is 3473
# this is 3474
# this is 3475
# this is 3476
# this is 3477
# this is 3478
# this is 3479
# this is 3480
# this is 3481
# this is 3482
# this is 3483
# this is 3484
# this is 3485
# this is 3486
# this is 3487
# this is 3488
# this is 3489
# this is 3490
# this is 3491
# this is 3492
# this is 3493
# this is 3494
# this is 3495
# this is 3496
# this is 3497
# this is 3498
# this is 3499
# this is 3500
# this is 3501
# this is 3502
# this is 3503
# this is 3504
# this is 3505
# this is 3506
# this is 3507
# this is 3508
# this is 3509
# this is 3510
# this is 3511
# this is 3512
# this is 3513
# this is 3514
# this is 3515
# this is 3516
# this is 3517
# this is 3518
# this is 3519
# this is 3520
# this is 3521
# this is 3522
# this is 3523
# this is 3524
# this is 3525
# this is 3526
# this is 3527
# this is 3528
# this is 3529
# this is 3530
# this is 3531
# this is 3532
# this is 3533
# this is 3534
# this is 3535
# this is 3536
# this is 3537
# this is 3538
# this is 3539
# this is 3540
# this is 3541
# this is 3542
# this is 3543
# this is 3544
# this is 3545
# this is 3546
# this is 3547
# this is 3548
# this is 3549
# this is 3550
# this is 3551
# this is 3552
# this is 3553
# this is 3554
# this is 3555
# this is 3556
# this is 3557
# this is 3558
# this is 3559
# this is 3560
# this is 3561
# this is 3562
# this is 3563
# this is 3564
# this is 3565
# this is 3566
# this is 3567
# this is 3568
# this is 3569
# this is 3570
# this is 3571
# this is 3572
# this is 3573
# this is 3574
# this is 3575
# this is 3576
# this is 3577
# this is 3578
# this is 3579
# this is 3580
# this is 3581
# this is 3582
# this is 3583
# this is 3584
# this is 3585
# this is 3586
# this is 3587
# this is 3588
# this is 3589
# this is 3590
# this is 3591
# this is 3592
# this is 3593
# this is 3594
# this is 3595
# this is 3596
# this is 3597
# this is 3598
# this is 3599
# this is 3600
# this is 3601
# this is 3602
# this is 3603
# this is 3604
# this is 3605
# this is 3606
# this is 3607
# this is 3608
# this is 3609
# this is 3610
# this is 3611
# this is 3612
# this is 3613
# this is 3614
# this is 3615
# this is 3616
# this is 3617
# this is 3618
# this is 3619
# this is 3620
# this is 3621
# this is 3622
# this is 3623
# this is 3624
# this is 3625
# this is 3626
# this is 3627
# this is 3628
# this is 3629
# this is 3630
# this is 3631
# this is 3632
# this is 3633
# this is 3634
# this is 3635
# this is 3636
# this is 3637
# this is 3638
# this is 3639
# this is 3640
# this is 3641
# this is 3642
# this is 3643
# this is 3644
# this is 3645
# this is 3646
# this is 3647
# this is 3648
# this is 3649
# this is 3650
# this is 3651
# this is 3652
# this is 3653
# this is 3654
# this is 3655
# this is 3656
# this is 3657
# this is 3658
# this is 3659
# this is 3660
# this is 3661
# this is 3662
# this is 3663
# this is 3664
# this is 3665
# this is 3666
# this is 3667
# this is 3668
# this is 3669
# this is 3670
# this is 3671
# this is 3672
# this is 3673
# this is 3674
# this is 3675
# this is 3676
# this is 3677
# this is 3678
# this is 3679
# this is 3680
# this is 3681
# this is 3682
# this is 3683
# this is 3684
# this is 3685
# this is 3686
# this is 3687
# this is 3688
# this is 3689
# this is 3690
# this is 3691
# this is 3692
# this is 3693
# this is 3694
# this is 3695
# this is 3696
# this is 3697
# this is 3698
# this is 3699
# this is 3700
# this is 3701
# this is 3702
# this is 3703
# this is 3704
# this is 3705
# this is 3706
# this is 3707
# this is 3708
# this is 3709
# this is 3710
# this is 3711
# this is 3712
# this is 3713
# this is 3714
# this is 3715
# this is 3716
# this is 3717
# this is 3718
# this is 3719
# this is 3720
# this is 3721
# this is 3722
# this is 3723
# this is 3724
# this is 3725
# this is 3726
# this is 3727
# this is 3728
# this is 3729
# this is 3730
# this is 3731
# this is 3732
# this is 3733
# this is 3734
# this is 3735
# this is 3736
# this is 3737
# this is 3738
# this is 3739
# this is 3740
# this is 3741
# this is 3742
# this is 3743
# this is 3744
# this is 3745
# this is 3746
# this is 3747
# this is 3748
# this is 3749
# this is 3750
# this is 3751
# this is 3752
# this is 3753
# this is 3754
# this is 3755
# this is 3756
# this is 3757
# this is 3758
# this is 3759
# this is 3760
# this is 3761
# this is 3762
# this is 3763
# this is 3764
# this is 3765
# this is 3766
# this is 3767
# this is 3768
# this is 3769
# this is 3770
# this is 3771
# this is 3772
# this is 3773
# this is 3774
# this is 3775
# this is 3776
# this is 3777
# ...
# this is 7605
# this is 7606
# this is 7607
# this is 7608
# this is 7609
# this is 7610
# this is 7611
# this is 7612
# this is 7613
# this is 7614
# this is 7615
# this is 7616
# this is 7617
# this is 7618
# this is 7619
# this is 7620
# this is 7621
# this is 7622
# this is 7623
# this is 7624
# this is 7625
# this is 7626
# this is 7627
# this is 7628
# this is 7629
# this is 7630
# this is 7631
# this is 7632
# this is 7633
# this is 7634
# this is 7635
# this is 7636
# this is 7637
# this is 7638
# this is 7639
# this is 7640
# this is 7641
# this is 7642
# this is 7643
# this is 7644
# this is 7645
# this is 7646
# this is 7647
# this is 7648
# this is 7649
# this is 7650
# this is 7651
# this is 7652
# this is 7653
# this is 7654
# this is 7655
# this is 7656
# this is 7657
# this is 7658
# this is 7659
# this is 7660
# this is 7661
# this is 7662
# this is 7663
# this is 7664
# this is 7665
# this is 7666
# this is 7667
# this is 7668
# this is 7669
# this is 7670
# this is 7671
# this is 7672
# this is 7673
# this is 7674
# this is 7675
# this is 7676
# this is 7677
# this is 7678
# this is 7679
# this is 7680
# this is 7681
# this is 7682
# this is 7683
# this is 7684
# this is 7685
# this is 7686
# this is 7687
# this is 7688
# this is 7689
# this is 7690
# this is 7691
# this is 7692
# this is 7693
# this is 7694
# this is 7695
# this is 7696
# this is 7697
# this is 7698
# this is 7699
# this is 7700
# this is 7701
# this is 7702
# this is 7703
# this is 7704
# this is 7705
# this is 7706
# this is 7707
# this is 7708
# this is 7709
# this is 7710
# this is 7711
# this is 7712
# this is 7713
# this is 7714
# this is 7715
# this is 7716
# this is 7717
# this is 7718
# this is 7719
# this is 7720
# this is 7721
# this is 7722
# this is 7723
# this is 7724
# this is 7725
# this is 7726
# this is 7727
# this is 7728
# this is 7729
# this is 7730
# this is 7731
# this is 7732
# this is 7733
# this is 7734
# this is 7735
# this is 7736
# this is 7737
# this is 7738
# this is 7739
# this is 7740
# this is 7741
# this is 7742
# this is 7743
# this is 7744
# this is 7745
# this is 7746
# this is 7747
# this is 7748
# this is 7749
# this is 7750
# this is 7751
# this is 7752
# this is 7753
# this is 7754
# this is 7755
# this is 7756
# this is 7757
# this is 7758
# this is 7759
# this is 7760
# this is 7761
# this is 7762
# this is 7763
# this is 7764
# this is 7765
# this is 7766
# this is 7767
# this is 7768
# this is 7769
# this is 7770
# this is 7771
# this is 7772
# this is 7773
# this is 7774
# this is 7775
# this is 7776
# this is 7777
# this is 7778
# this is 7779
# this is 7780
# this is 7781
# this is 7782
# this is 7783
# this is 7784
# this is 7785
# this is 7786
# this is 7787
# this is 7788
# this is 7789
# this is 7790
# this is 7791
# this is 7792
# this is 7793
# this is 7794
# this is 7795
# this is 7796
# this is 7797
# this is 7798
# this is 7799
# this is 7800
# this is 7801
# this is 7802
# this is 7803
# this is 7804
# this is 7805
# this is 7806
# this is 7807
# this is 7808
# this is 7809
# this is 7810
# this is 7811
# this is 7812
# this is 7813
# this is 7814
# this is 7815
# this is 7816
# this is 7817
# this is 7818
# this is 7819
# this is 7820
# this is 7821
# this is 7822
# this is 7823
# this is 7824
# this is 7825
# this is 7826
# this is 7827
# this is 7828
# this is 7829
# this is 7830
# this is 7831
# this is 7832
# this is 7833
# this is 7834
# this is 7835
# this is 7836
# this is 7837
# this is 7838
# this is 7839
# this is 7840
# this is 7841
# this is 7842
# this is 7843
# this is 7844
# this is 7845
# this is 7846
# this is 7847
# this is 7848
# this is 7849
# this is 7850
# this is 7851
# this is 7852
# this is 7853
# this is 7854
# this is 7855
# this is 7856
# this is 7857
# this is 7858
# this is 7859
# this is 7860
# this is 7861
# this is 7862
# this is 7863
# this is 7864
# this is 7865
# this is 7866
# this is 7867
# this is 7868
# this is 7869
# this is 7870
# this is 7871
# this is 7872
# this is 7873
# this is 7874
# this is 7875
# this is 7876
# this is 7877
# this is 7878
# this is 7879
# this is 7880
# this is 7881
# this is 7882
# this is 7883
# this is 7884
# this is 7885
# this is 7886
# this is 7887
# this is 7888
# this is 7889
# this is 7890
# this is 7891
# this is 7892
# this is 7893
# this is 7894
# this is 7895
# this is 7896
# this is 7897
# this is 7898
# this is 7899
# this is 7900
# this is 7901
# this is 7902
# this is 7903
# this is 7904
# this is 7905
# this is 7906
# this is 7907
# this is 7908
# this is 7909
# this is 7910
# this is 7911
# this is 7912
# this is 7913
# this is 7914
# this is 7915
# this is 7916
# this is 7917
# this is 7918
# this is 7919
# this is 7920
# this is 7921
# this is 7922
# this is 7923
# this is 7924
# this is 7925
# this is 7926
# this is 7927
# this is 7928
# this is 7929
# this is 7930
# this is 7931
# this is 7932
# this is 7933
# this is 7934
# this is 7935
# this is 7936
# this is 7937
# this is 7938
# this is 7939
# this is 7940
# this is 7941
# this is 7942
# this is 7943
# this is 7944
# this is 7945
# this is 7946
# this is 7947
# this is 7948
# this is 7949
# this is 7950
# this is 7951
# this is 7952
# this is 7953
# this is 7954
# this is 7955
# this is 7956
# this is 7957
# this is 7958
# this is 7959
# this is 7960
# this is 7961
# this is 7962
# this is 7963
# this is 7964
# this is 7965
# this is 7966
# this is 7967
# this is 7968
# this is 7969
# this is 7970
# this is 7971
# this is 7972
# this is 7973
# this is 7974
# this is 7975
# this is 7976
# this is 7977
# this is 7978
# this is 7979
# this is 7980
# this is 7981
# this is 7982
# this is 7983
# this is 7984
# this is 7985
# this is 7986
# this is 7987
# this is 7988
# this is 7989
# this is 7990
# this is 7991
# this is 7992
# this is 7993
# this is 7994
# this is 7995
# this is 7996
# this is 7997
# this is 7998
# this is 7999
# this is 8000
# this is 8001
# this is 8002
# this is 8003
# this is 8004
# this is 8005
# this is 8006
# this is 8007
# this is 8008
# this is 8009
# this is 8010
# this is 8011
# this is 8012
# this is 8013
# this is 8014
# this is 8015
# this is 8016
# this is 8017
# this is 8018
# this is 8019
# this is 8020
# this is 8021
# this is 8022
# this is 8023
# this is 8024
# this is 8025
# this is 8026
# this is 8027
# this is 8028
# this is 8029
# this is 8030
# this is 8031
# this is 8032
# this is 8033
# this is 8034
# this is 8035
# this is 8036
# this is 8037
# this is 8038
# this is 8039
# this is 8040
# this is 8041
# this is 8042
# this is 8043
# this is 8044
# this is 8045
# this is 8046
# this is 8047
# this is 8048
# this is 8049
# this is 8050
# this is 8051
# this is 8052
# this is 8053
# this is 8054
# this is 8055
# this is 8056
# this is 8057
# this is 8058
# this is 8059
# this is 8060
# this is 8061
# this is 8062
# this is 8063
# this is 8064
# this is 8065
# this is 8066
# this is 8067
# this is 8068
# this is 8069
# this is 8070
# this is 8071
# this is 8072
# this is 8073
# this is 8074
# this is 8075
# this is 8076
# this is 8077
# this is 8078
# this is 8079
# this is 8080
# this is 8081
# this is 8082
# this is 8083
# this is 8084
# this is 8085
# this is 8086
# this is 8087
# this is 8088
# this is 8089
# this is 8090
# this is 8091
# this is 8092
# this is 8093
# this is 8094
# this is 8095
# this is 8096
# this is 8097
# this is 8098
# this is 8099
# this is 8100
# this is 8101
# this is 8102
# this is 8103
# this is 8104
# this is 8105
# this is 8106
# this is 8107
# this is 8108
# this is 8109
# this is 8110
# this is 8111
# this is 8112
# this is 8113
# this is 8114
# this is 8115
# this is 8116
# this is 8117
# this is 8118
# this is 8119
# this is 8120
# this is 8121
# this is 8122
# this is 8123
# this is 8124
# this is 8125
# this is 8126
# this is 8127
# this is 8128
# this is 8129
# this is 8130
# this is 8131
# this is 8132
# this is 8133
# this is 8134
# this is 8135
# this is 8136
# this is 8137
# this is 8138
# this is 8139
# this is 8140
# this is 8141
# this is 8142
# this is 8143
# this is 8144
# this is 8145
# this is 8146
# this is 8147
# this is 8148
# this is 8149
# this is 8150
# this is 8151
# this is 8152
# this is 8153
# this is 8154
# this is 8155
# this is 8156
# this is 8157
# this is 8158
# this is 8159
# this is 8160
# this is 8161
# this is 8162
# this is 8163
# this is 8164
# this is 8165
# this is 8166
# this is 8167
# this is 8168
# this is 8169
# this is 8170
# this is 8171
# this is 8172
# this is 8173
# this is 8174
# this is 8175
# this is 8176
# this is 8177
# this is 8178
# this is 8179
# this is 8180
# this is 8181
# this is 8182
# this is 8183
# this is 8184
# this is 8185
# this is 8186
# this is 8187
# this is 8188
# this is 8189
# this is 8190
# this is 8191
# this is 8192
# this is 8193
# this is 8194
# this is 8195
# this is 8196
# this is 8197
# this is 8198
# this is 8199
# this is 8200
# this is 8201
# this is 8202
# this is 8203
# this is 8204
# this is 8205
# this is 8206
# this is 8207
# this is 8208
# this is 8209
# this is 8210
# this is 8211
# this is 8212
# this is 8213
# this is 8214
# this is 8215
# this is 8216
# this is 8217
# this is 8218
# this is 8219
# this is 8220
# this is 8221
# this is 8222
# this is 8223
# this is 8224
# this is 8225
# this is 8226
# this is 8227
# this is 8228
# this is 8229
# this is 8230
# this is 8231
# this is 8232
# this is 8233
# this is 8234
# this is 8235
# this is 8236
# this is 8237
# this is 8238
# this is 8239
# this is 8240
# this is 8241
# this is 8242
# this is 8243
# this is 8244
# this is 8245
# this is 8246
# this is 8247
# this is 8248
# this is 8249
# this is 8250
# this is 8251
# this is 8252
# this is 8253
# this is 8254
# this is 8255
# this is 8256
# this is 8257
# this is 8258
# this is 8259
# this is 8260
# this is 8261
# this is 8262
# this is 8263
# this is 8264
# this is 8265
# this is 8266
# this is 8267
# this is 8268
# this is 8269
# this is 8270
# this is 8271
# this is 8272
# this is 8273
# this is 8274
# this is 8275
# this is 8276
# this is 8277
# this is 8278
# this is 8279
# this is 8280
# this is 8281
# this is 8282
# this is 8283
# this is 8284
# this is 8285
# this is 8286
# this is 8287
# this is 8288
# this is 8289
# this is 8290
# this is 8291
# this is 8292
# this is 8293
# this is 8294
# this is 8295
# this is 8296
# this is 8297
# this is 8298
# this is 8299
# this is 8300
# this is 8301
# this is 8302
# this is 8303
# this is 8304
# this is 8305
# this is 8306
# this is 8307
# this is 8308
# this is 8309
# this is 8310
# this is 8311
# this is 8312
# this is 8313
# this is 8314
# this is 8315
# this is 8316
# this is 8317
# this is 8318
# this is 8319
# this is 8320
# this is 8321
# this is 8322
# this is 8323
# this is 8324
# this is 8325
# this is 8326
# this is 8327
# this is 8328
# this is 8329
# this is 8330
# this is 8331
# this is 8332
# this is 8333
# this is 8334
# this is 8335
# this is 8336
# this is 8337
# this is 8338
# this is 8339
# this is 8340
# this is 8341
# this is 8342
# this is 8343
# this is 8344
# this is 8345
# this is 8346
# this is 8347
# this is 8348
# this is 8349
# this is 8350
# this is 8351
# this is 8352
# this is 8353
# this is 8354
# this is 8355
# this is 8356
# this is 8357
# this is 8358
# this is 8359
# this is 8360
# this is 8361
# this is 8362
# this is 8363
# this is 8364
# this is 8365
# this is 8366
# this is 8367
# this is 8368
# this is 8369
# this is 8370
# this is 8371
# this is 8372
# this is 8373
# this is 8374
# this is 8375
# this is 8376
# this is 8377
# this is 8378
# this is 8379
# this is 8380
# this is 8381
# this is 8382
# this is 8383
# this is 8384
# this is 8385
# this is 8386
# this is 8387
# this is 8388
# this is 8389
# this is 8390
# this is 8391
# this is 8392
# this is 8393
# this is 8394
# this is 8395
# this is 8396
# this is 8397
# this is 8398
# this is 8399
# this is 8400
# this is 8401
# this is 8402
# this is 8403
# this is 8404
# this is 8405
# this is 8406
# this is 8407
# this is 8408
# this is 8409
# this is 8410
# this is 8411
# this is 8412
# this is 8413
# this is 8414
# this is 8415
# this is 8416
# this is 8417
# this is 8418
# this is 8419
# this is 8420
# this is 8421
# this is 8422
# this is 8423
# this is 8424
# this is 8425
# this is 8426
# this is 8427
# this is 8428
# this is 8429
# this is 8430
# this is 8431
# this is 8432
# this is 8433
# this is 8434
# this is 8435
# this is 8436
# this is 8437
# this is 8438
# this is 8439
# this is 8440
# this is 8441
# this is 8442
# this is 8443
# this is 8444
# this is 8445
# this is 8446
# this is 8447
# this is 8448
# this is 8449
# this is 8450
# this is 8451
# this is 8452
# this is 8453
# this is 8454
# this is 8455
# this is 8456
# this is 8457
# this is 8458
# this is 8459
# this is 8460
# this is 8461
# this is 8462
# this is 8463
# this is 8464
# this is 8465
# this is 8466
# this is 8467
# this is 8468
# this is 8469
# this is 8470
# this is 8471
# this is 8472
# this is 8473
# this is 8474
# this is 8475
# this is 8476
# this is 8477
# this is 8478
# this is 8479
# this is 8480
# this is 8481
# this is 8482
# this is 8483
# this is 8484
# this is 8485
# this is 8486
# this is 8487
# this is 8488
# this is 8489
# this is 8490
# this is 8491
# this is 8492
# this is 8493
# this is 8494
# this is 8495
# this is 8496
# this is 8497
# this is 8498
# this is 8499
# this is 8500
# this is 8501
# this is 8502
# this is 8503
# this is 8504
# this is 8505
# this is 8506
# this is 8507
# this is 8508
# this is 8509
# this is 8510
# this is 8511
# this is 8512
# this is 8513
# this is 8514
# this is 8515
# this is 8516
# this is 8517
# this is 8518
# this is 8519
# this is 8520
# this is 8521
# this is 8522
# this is 8523
# this is 8524
# this is 8525
# this is 8526
# this is 8527
# this is 8528
# this is 8529
# this is 8530
# this is 8531
# this is 8532
# this is 8533
# this is 8534
# this is 8535
# this is 8536
# this is 8537
# this is 8538
# this is 8539
# this is 8540
# this is 8541
# this is 8542
# this is 8543
# this is 8544
# this is 8545
# this is 8546
# this is 8547
# this is 8548
# this is 8549
# this is 8550
# this is 8551
# this is 8552
# this is 8553
# this is 8554
# this is 8555
# this is 8556
# this is 8557
# this is 8558
# this is 8559
# this is 8560
# this is 8561
# this is 8562
# this is 8563
# this is 8564
# this is 8565
# this is 8566
# this is 8567
# this is 8568
# this is 8569
# this is 8570
# this is 8571
# this is 8572
# this is 8573
# this is 8574
# this is 8575
# this is 8576
# this is 8577
# this is 8578
# this is 8579
# this is 8580
# this is 8581
# this is 8582
# this is 8583
# this is 8584
# this is 8585
# this is 8586
# this is 8587
# this is 8588
# this is 8589
# this is 8590
# this is 8591
# this is 8592
# this is 8593
# this is 8594
# this is 8595
# this is 8596
# this is 8597
# this is 8598
# this is 8599
# this is 8600
# this is 8601
# this is 8602
# this is 8603
# this is 8604
# this is 8605
# this is 8606
# this is 8607
# this is 8608
# this is 8609
# this is 8610
# this is 8611
# this is 8612
# this is 8613
# this is 8614
# this is 8615
# this is 8616
# this is 8617
# this is 8618
# this is 8619
# this is 8620
# this is 8621
# this is 8622
# this is 8623
# this is 8624
# this is 8625
# this is 8626
# this is 8627
# this is 8628
# this is 8629
# this is 8630
# this is 8631
# this is 8632
# this is 8633
# this is 8634
# this is 8635
# this is 8636
# this is 8637
# this is 8638
# this is 8639
# this is 8640
# this is 8641
# this is 8642
# this is 8643
# this is 8644
# this is 8645
# this is 8646
# this is 8647
# this is 8648
# this is 8649
# this is 8650
# this is 8651
# this is 8652
# this is 8653
# this is 8654
# this is 8655
# this is 8656
# this is 8657
# this is 8658
# this is 8659
# this is 8660
# this is 8661
# this is 8662
# this is 8663
# this is 8664
# this is 8665
# this is 8666
# this is 8667
# this is 8668
# this is 8669
# this is 8670
# this is 8671
# this is 8672
# this is 8673
# this is 8674
# this is 8675
# this is 8676
# this is 8677
# this is 8678
# this is 8679
# this is 8680
# this is 8681
# this is 8682
# this is 8683
# this is 8684
# this is 8685
# this is 8686
# this is 8687
# this is 8688
# this is 8689
# this is 8690
# this is 8691
# this is 8692
# this is 8693
# this is 8694
# this is 8695
# this is 8696
# this is 8697
# this is 8698
# this is 8699
# this is 8700
# this is 8701
# this is 8702
# this is 8703
# this is 8704
# this is 8705
# this is 8706
# this is 8707
# this is 8708
# this is 8709
# this is 8710
# this is 8711
# this is 8712
# this is 8713
# this is 8714
# this is 8715
# this is 8716
# this is 8717
# this is 8718
# this is 8719
# this is 8720
# this is 8721
# this is 8722
# this is 8723
# this is 8724
# this is 8725
# this is 8726
# this is 8727
# this is 8728
# this is 8729
# this is 8730
# this is 8731
# this is 8732
# this is 8733
# this is 8734
# this is 8735
# this is 8736
# this is 8737
# this is 8738
# this is 8739
# this is 8740
# this is 8741
# this is 8742
# this is 8743
# this is 8744
# this is 8745
# this is 8746
# this is 8747
# this is 8748
# this is 8749
# this is 8750
# this is 8751
# this is 8752
# this is 8753
# this is 8754
# this is 8755
# this is 8756
# this is 8757
# this is 8758
# this is 8759
# this is 8760
# this is 8761
# this is 8762
# this is 8763
# this is 8764
# this is 8765
# this is 8766
# this is 8767
# this is 8768
# this is 8769
# this is 8770
# this is 8771
# this is 8772
# this is 8773
# this is 8774
# this is 8775
# this is 8776
# this is 8777
# this is 8778
# this is 8779
# this is 8780
# this is 8781
# this is 8782
# this is 8783
# this is 8784
# this is 8785
# this is 8786
# this is 8787
# this is 8788
# this is 8789
# this is 8790
# this is 8791
# this is 8792
# this is 8793
# this is 8794
# this is 8795
# this is 8796
# this is 8797
# this is 8798
# this is 8799
# this is 8800
# this is 8801
# this is 8802
# this is 8803
# this is 8804
# this is 8805
# this is 8806
# this is 8807
# this is 8808
# this is 8809
# this is 8810
# this is 8811
# this is 8812
# this is 8813
# this is 8814
# this is 8815
# this is 8816
# this is 8817
# this is 8818
# this is 8819
# this is 8820
# this is 8821
# this is 8822
# this is 8823
# this is 8824
# this is 8825
# this is 8826
# this is 8827
# this is 8828
# this is 8829
# this is 8830
# this is 8831
# this is 8832
# (2441, 1, 64, 16, 64, 64)

# %%
len()

# %%
# 设置分布式环境
# local_rank = int(os.environ.get("LOCAL_RANK", 0))



crop_size=['128','256']
file_insert=crop_size[0]
Precrop_dataset_for_train_path = f"/mnt/wangc/EXACT09/Precrop_dataset_for_EXACT09_{file_insert}"
Precrop_dataset_for_train_raw_path = Precrop_dataset_for_train_path+"/image"
Precrop_dataset_for_train_label_path = Precrop_dataset_for_train_path+"/label"

raw_case_name_list = os.listdir(Precrop_dataset_for_train_raw_path)
# print(len(raw_case_name_list))

lidc_dataset_for_train_path=f'/mnt/wangc/LIDC/Precrop_dataset_for_LIDC-IDRI_{file_insert}'
lidc_dataset_for_train_raw_path =lidc_dataset_for_train_path+"/image"
lidc_dataset_for_train_label_path = lidc_dataset_for_train_path+"/label"
lidc_raw_case_name_list = os.listdir(lidc_dataset_for_train_raw_path)
# print(len(lidc_raw_case_name_list))



# file_path1=f'/home/wangc/now/NaviAirway/saved_var/exact09_{file_insert}_op_embeddings_data.pkl'
# file_path2=f'/home/wangc/now/NaviAirway/saved_var/lidc_{file_insert}_op_embeddings_data.pkl'
# with open(file_path1, 'rb') as file:
#     loaded_data = pickle.load(file)
#     exact_embeddings_list = loaded_data['embeddings_list']
#     exact_embeddings_dict = loaded_data['embeddings_dict']
# exact_stacked_embeddings_numpy = np.stack(exact_embeddings_list, axis=0)
# print(exact_stacked_embeddings_numpy.shape)
# with open(file_path2, 'rb') as file:
#     loaded_data = pickle.load(file)
#     lidc_embeddings_list = loaded_data['embeddings_list']
#     lidc_embeddings_dict = loaded_data['embeddings_dict']
# lidc_stacked_embeddings_numpy = np.stack(lidc_embeddings_list, axis=0)
# print(lidc_stacked_embeddings_numpy.shape)
# test_names = ['LIDC_IDRI_0066', 'LIDC_IDRI_0328', 'LIDC_IDRI_0376',
# 'LIDC_IDRI_0441',  'LIDC_IDRI_0744', 'LIDC_IDRI_1004','EXACT09_CASE13',
# 'EXACT09_CASE08', 'EXACT09_CASE01', 'EXACT09_CASE05']

# i=0
# new_list=[]
# new_dict={}
# for key,v in exact_embeddings_dict.items():
#     if key[:14] not in test_names:
#         new_list.append(exact_embeddings_list[i])
#         new_dict[key]=exact_embeddings_dict[key]
#     i+=1
# exact_embeddings_list=new_list
# exact_embeddings_dict=new_dict

# i=0
# new_list=[]
# new_dict={}
# for key,v in lidc_embeddings_dict.items():
#     if key[:14] not in test_names:
#         new_list.append(lidc_embeddings_list[i])
#         new_dict[key]=lidc_embeddings_dict[key]
#     i+=1
# lidc_embeddings_list=new_list
# lidc_embeddings_dict=new_dict

# exact_stacked_embeddings_numpy = np.stack(exact_embeddings_list, axis=0)
# lidc_stacked_embeddings_numpy = np.stack(lidc_embeddings_list, axis=0)

# exact_lidc_concatenated_array = np.concatenate((exact_stacked_embeddings_numpy, lidc_stacked_embeddings_numpy), axis=0)
# merged_dict={**exact_embeddings_dict,**lidc_embeddings_dict}
# merged_list=list(exact_embeddings_dict.keys())+list(lidc_embeddings_dict.keys())
# print(exact_stacked_embeddings_numpy.shape,lidc_stacked_embeddings_numpy.shape,exact_lidc_concatenated_array.shape)



# exact_lidc_concatenated_array = np.concatenate((exact_stacked_embeddings_numpy, lidc_stacked_embeddings_numpy), axis=0)
# merged_dict={**exact_embeddings_dict,**lidc_embeddings_dict}
# merged_list=raw_case_name_list+lidc_raw_case_name_list
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 113
#     109 file_path2 = '/mnt/wangc/NaviAirway/saved_var/lidc_128_op_ae2_segmentation_data.pkl'
#     110 test_names = ['LIDC_IDRI_0066', 'LIDC_IDRI_0328', 'LIDC_IDRI_0376',
#     111 'LIDC_IDRI_0441',  'LIDC_IDRI_0744', 'LIDC_IDRI_1004','EXACT09_CASE13',
#     112 'EXACT09_CASE08', 'EXACT09_CASE01', 'EXACT09_CASE05']
# --> 113 exact_lidc_concatenated_array , merged_dict, merged_list = load_partial_embeddings(file_path1, file_path2,train_names=None,test_names=test_names)
#     114 print(len(merged_list))
#
# File ~/now/NaviAirway/al_method/active_learning_utils.py:555, in load_partial_embeddings(file_path1, file_path2, train_names, test_names)
#     554 def load_partial_embeddings(file_path1, file_path2, train_names=None,test_names=None):
# --> 555     with open(file_path1, 'rb') as file:
#     556         loaded_data = pickle.load(file)
#     557         exact_embeddings_list = loaded_data['embeddings_list']
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/wangc/NaviAirway/saved_var/exact09_128_op_ae2_segmentation_data.pkl'

# %%
file_path1 = '/mnt/wangc/NaviAirway/saved_var/exact09_128_op_ae2_segmentation_data'
file_path2 = '/mnt/wangc/NaviAirway/saved_var/lidc_128_op_ae2_segmentation_data.pkl'
test_names = ['LIDC_IDRI_0066', 'LIDC_IDRI_0328', 'LIDC_IDRI_0376',
'LIDC_IDRI_0441',  'LIDC_IDRI_0744', 'LIDC_IDRI_1004','EXACT09_CASE13',
'EXACT09_CASE08', 'EXACT09_CASE01', 'EXACT09_CASE05']
exact_lidc_concatenated_array , merged_dict, merged_list = load_partial_embeddings(file_path1, file_path2,train_names=None,test_names=test_names)
print(len(merged_list))

# %%
import numpy as np
import torch
import os
# os.environ["CUDA_VISIBLE_DEVICES"] = "4,5"
import skimage.io as io
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from torch import from_numpy as from_numpy
from matplotlib.colors import ListedColormap
import matplotlib.patches as mpatches

from active_learning_utils import process_images,visualize_and_return_indices,show_all_2d_img_with_labels,kmeans,save_obj,load_obj,load_partial_embeddings
import pickle

import sys
sys.path.append('../')  # 将上一层目录添加到模块搜索路径中
from func.model_arch2 import SegAirwayModel

import torch.utils.data as data_utils


import edt


import torch
import torch.distributed as dist
from torch.nn.parallel import DistributedDataParallel
from torch.utils.data.distributed import DistributedSampler


# 设置分布式环境
# local_rank = int(os.environ.get("LOCAL_RANK", 0))



crop_size=['128','256']
file_insert=crop_size[0]
Precrop_dataset_for_train_path = f"/mnt/wangc/EXACT09/Precrop_dataset_for_EXACT09_{file_insert}"
Precrop_dataset_for_train_raw_path = Precrop_dataset_for_train_path+"/image"
Precrop_dataset_for_train_label_path = Precrop_dataset_for_train_path+"/label"

raw_case_name_list = os.listdir(Precrop_dataset_for_train_raw_path)
# print(len(raw_case_name_list))

lidc_dataset_for_train_path=f'/mnt/wangc/LIDC/Precrop_dataset_for_LIDC-IDRI_{file_insert}'
lidc_dataset_for_train_raw_path =lidc_dataset_for_train_path+"/image"
lidc_dataset_for_train_label_path = lidc_dataset_for_train_path+"/label"
lidc_raw_case_name_list = os.listdir(lidc_dataset_for_train_raw_path)
# print(len(lidc_raw_case_name_list))



# file_path1=f'/home/wangc/now/NaviAirway/saved_var/exact09_{file_insert}_op_embeddings_data.pkl'
# file_path2=f'/home/wangc/now/NaviAirway/saved_var/lidc_{file_insert}_op_embeddings_data.pkl'
# with open(file_path1, 'rb') as file:
#     loaded_data = pickle.load(file)
#     exact_embeddings_list = loaded_data['embeddings_list']
#     exact_embeddings_dict = loaded_data['embeddings_dict']
# exact_stacked_embeddings_numpy = np.stack(exact_embeddings_list, axis=0)
# print(exact_stacked_embeddings_numpy.shape)
# with open(file_path2, 'rb') as file:
#     loaded_data = pickle.load(file)
#     lidc_embeddings_list = loaded_data['embeddings_list']
#     lidc_embeddings_dict = loaded_data['embeddings_dict']
# lidc_stacked_embeddings_numpy = np.stack(lidc_embeddings_list, axis=0)
# print(lidc_stacked_embeddings_numpy.shape)
# test_names = ['LIDC_IDRI_0066', 'LIDC_IDRI_0328', 'LIDC_IDRI_0376',
# 'LIDC_IDRI_0441',  'LIDC_IDRI_0744', 'LIDC_IDRI_1004','EXACT09_CASE13',
# 'EXACT09_CASE08', 'EXACT09_CASE01', 'EXACT09_CASE05']

# i=0
# new_list=[]
# new_dict={}
# for key,v in exact_embeddings_dict.items():
#     if key[:14] not in test_names:
#         new_list.append(exact_embeddings_list[i])
#         new_dict[key]=exact_embeddings_dict[key]
#     i+=1
# exact_embeddings_list=new_list
# exact_embeddings_dict=new_dict

# i=0
# new_list=[]
# new_dict={}
# for key,v in lidc_embeddings_dict.items():
#     if key[:14] not in test_names:
#         new_list.append(lidc_embeddings_list[i])
#         new_dict[key]=lidc_embeddings_dict[key]
#     i+=1
# lidc_embeddings_list=new_list
# lidc_embeddings_dict=new_dict

# exact_stacked_embeddings_numpy = np.stack(exact_embeddings_list, axis=0)
# lidc_stacked_embeddings_numpy = np.stack(lidc_embeddings_list, axis=0)

# exact_lidc_concatenated_array = np.concatenate((exact_stacked_embeddings_numpy, lidc_stacked_embeddings_numpy), axis=0)
# merged_dict={**exact_embeddings_dict,**lidc_embeddings_dict}
# merged_list=list(exact_embeddings_dict.keys())+list(lidc_embeddings_dict.keys())
# print(exact_stacked_embeddings_numpy.shape,lidc_stacked_embeddings_numpy.shape,exact_lidc_concatenated_array.shape)



# exact_lidc_concatenated_array = np.concatenate((exact_stacked_embeddings_numpy, lidc_stacked_embeddings_numpy), axis=0)
# merged_dict={**exact_embeddings_dict,**lidc_embeddings_dict}
# merged_list=raw_case_name_list+lidc_raw_case_name_list



file_path1='/home/wangc/now/NaviAirway/saved_var/exact09_128_op_ae2_segmentation_data'
file_path2='/mnt/wangc/NaviAirway/saved_var/lidc_128_op_ae2_segmentation_data.pkl'
test_names = ['LIDC_IDRI_0066', 'LIDC_IDRI_0328', 'LIDC_IDRI_0376',
'LIDC_IDRI_0441',  'LIDC_IDRI_0744', 'LIDC_IDRI_1004','EXACT09_CASE13',
'EXACT09_CASE08', 'EXACT09_CASE01', 'EXACT09_CASE05']
exact_lidc_concatenated_array , merged_dict, merged_list = load_partial_embeddings(file_path1, file_path2,train_names=None,test_names=test_names)
print(len(merged_list))
# Out:
# 无法启动 Kernel。
#
# ENOSPC: no space left on device, open '/home/wangc/.local/share/jupyter/runtime/kernel-v2-1978730xCvWzDRsHJBG.json'.
#
# 有关更多详细信息，请查看 Jupyter <a href='command:jupyter.viewOutput'>log</a>。

# %% [markdown]
# ###     数据，这些数据是已经被裁剪过的3d patch

# %%
Precrop_dataset_for_train_path = "/mnt/wangc/EXACT09/Precrop_dataset_for_EXACT09_128"
Precrop_dataset_for_train_raw_path = Precrop_dataset_for_train_path+"/image"
Precrop_dataset_for_train_label_path = Precrop_dataset_for_train_path+"/label"

raw_case_name_list = os.listdir(Precrop_dataset_for_train_raw_path)
print(len(raw_case_name_list))
# raw_case_name_list = os.listdir(Precrop_dataset_for_train_label_path)

#二次聚类

# Precrop_dataset_for_train_path = "/mnt/share102/cs22-wangc/EXACT09/Cluster/class0"
# Precrop_dataset_for_train_raw_path = Precrop_dataset_for_train_path+"/image"
# Precrop_dataset_for_train_label_path = Precrop_dataset_for_train_path+"/label"

# raw_case_name_list = os.listdir(Precrop_dataset_for_train_raw_path)
# # raw_case_name_list = os.listdir(Precrop_dataset_for_train_label_path)

lidc_dataset_for_train_path='/mnt/wangc/LIDC/Precrop_dataset_for_LIDC-IDRI_128'
lidc_dataset_for_train_raw_path =lidc_dataset_for_train_path+"/image"
lidc_dataset_for_train_label_path = lidc_dataset_for_train_path+"/label"
lidc_raw_case_name_list = os.listdir(lidc_dataset_for_train_raw_path)
print(len(lidc_raw_case_name_list))
# Out:
# 8832
# 21760

# %% [markdown]
# ### 需要对数据进行进一步变化

# %%
class Random3DCrop_np(object):
    def __init__(self, output_size):
        assert isinstance(output_size, (int, tuple)), 'Attention: random 3D crop output size: an int or a tuple (length:3)'
        if isinstance(output_size, int):
            self.output_size=(output_size, output_size, output_size)
        else:
            assert len(output_size)==3, 'Attention: random 3D crop output size: a tuple (length:3)'
            self.output_size=output_size
        
    def random_crop_start_point(self, input_size):
        assert len(input_size)==3, 'Attention: random 3D crop output size: a tuple (length:3)'
        d, h, w=input_size
        d_new, h_new, w_new=self.output_size
        
        d_new = min(d, d_new)
        h_new = min(h, h_new)
        w_new = min(w, w_new)
        
        assert (d>=d_new and h>=h_new and w>=w_new), "Attention: input size should >= crop size; now, input_size is "+str((d,h,w))+", while output_size is "+str((d_new, h_new, w_new))
        
        d_start=np.random.randint(0, d-d_new+1)
        h_start=np.random.randint(0, h-h_new+1)
        w_start=np.random.randint(0, w-w_new+1)
        
        return d_start, h_start, w_start
    
    def __call__(self, img_3d, start_points=None):
        img_3d=np.array(img_3d)
        
        d, h, w=img_3d.shape
        d_new, h_new, w_new=self.output_size
        
        if start_points == None:
            start_points = self.random_crop_start_point(img_3d.shape)
        
        d_start, h_start, w_start = start_points
        d_end = min(d_start+d_new, d)
        h_end = min(h_start+h_new, h)
        w_end = min(w_start+w_new, w)
        
        crop=img_3d[d_start:d_end, h_start:h_end, w_start:w_end]
        
        return crop

class Normalization_np(object):
    def __init__(self, windowMin, windowMax):
        self.name = 'ManualNormalization'
        assert isinstance(windowMax, (int,float))
        assert isinstance(windowMin, (int,float))
        self.windowMax = windowMax
        self.windowMin = windowMin
    
    def __call__(self, img_3d):
        img_3d_norm = np.clip(img_3d, self.windowMin, self.windowMax)
        img_3d_norm-=np.min(img_3d_norm)
        max_99_val=np.percentile(img_3d_norm, 99)
        if max_99_val>0:
            img_3d_norm = img_3d_norm/max_99_val*255
        return img_3d_norm
crop_size = (32, 128, 128)
windowMin=-1000
windowMax=150
random3dcrop=Random3DCrop_np(crop_size)
normalization=Normalization_np(windowMin, windowMax)

# %%
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.patches as mpatches  # Add this import statement


data_shape = exact_lidc_concatenated_array.shape

X_t = exact_lidc_concatenated_array.reshape(data_shape[0], -1)


# 创建 K 均值聚类模型并指定初始中心
# kmeans = KMeans(n_clusters=2, init=initial_centers, n_init=1, random_state=0)
kmeans = KMeans(n_clusters=2, random_state=0)
# 执行聚类
kmeans.fit(X_t)

# 获取聚类标签
cluster_labels = kmeans.labels_

# 将聚类结果添加到 X_t 中作为最后一列
X_t_with_labels = np.column_stack((X_t, cluster_labels.reshape(-1, 1)))

N=X_t.shape[0]
# 使用 perplexity 为 50 的 t-SNE 进行嵌入
tsne = TSNE(n_components=2, perplexity=70)
X_embedded_2d = tsne.fit_transform(X_t_with_labels)
embedding_dict = {merged_list[i]: X_embedded_2d[i] for i in range(N)}


# 使用 t-SNE 进行降维
threshold_dim1 = 20000  # 调整阈值
threshold_dim2 = 20000  # 调整阈值

# 筛选出维度值在一定范围内的数据
filtered_indices = np.where((abs(X_embedded_2d[:, 0]) < threshold_dim1) & (abs(X_embedded_2d[:, 1]) < threshold_dim2))[0]

# 筛选出符合阈值的数据
filtered_embeddings = X_embedded_2d[filtered_indices]


# 绘制二维散点图，只绘制符合阈值的数据
# 可视化二维嵌入并根据聚类标签着色
# colors = list(mcolors.TABLEAU_COLORS.values())
# custom_cmap = mcolors.ListedColormap(colors)


unique_labels = np.unique(cluster_labels)
cmap = plt.get_cmap('viridis', len(unique_labels))
colors = [cmap(i) for i in range(len(unique_labels))]

# query1_points = [True if name in query_list1 else False for name in embeddings_dict.keys()]
# query2_points = [True if name in query_list2 else False for name in embeddings_dict.keys()]
# query3_points = [True if name in query_list3 else False for name in embeddings_dict.keys()]
# # 使用 ListedColormap 为不同的聚类簇指定颜色

custom_cmap = ListedColormap(colors)
# 创建图例标签
legend_labels = [f'class{label}' for label in np.unique(cluster_labels)]

# 创建图例句柄
legend_handles = [mpatches.Patch(color=colors[i], label=legend_labels[i]) for i in range(len(unique_labels))]

plt.figure(figsize=(8, 6), dpi=100)
plt.scatter(filtered_embeddings[:, 0], filtered_embeddings[:, 1], c=cluster_labels[filtered_indices], cmap=custom_cmap)
plt.title("t-SNE 2D Embedding with Cluster Coloring (Perplexity=70)")

# 
# 添加图例
plt.legend(handles=legend_handles, loc='upper right')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 8
#       4 import matplotlib.colors as mcolors
#       5 import matplotlib.patches as mpatches  # Add this import statement
# ----> 8 data_shape = exact_lidc_concatenated_array.shape
#      10 X_t = exact_lidc_concatenated_array.reshape(data_shape[0], -1)
#      13 # 创建 K 均值聚类模型并指定初始中心
#      14 # kmeans = KMeans(n_clusters=2, init=initial_centers, n_init=1, random_state=0)
#
# NameError: name 'exact_lidc_concatenated_array' is not defined

# %% [markdown]
# ### 设置device、model、权重

# %%
device = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')
model=SegAirwayModel(in_channels=1, out_channels=2)
model.to(device)
load_pkl='/home/wangc/now/NaviAirway/checkpoint/abc_checkpoint_sample_org_33.pkl'
checkpoint = torch.load(load_pkl)
model.load_state_dict(checkpoint['model_state_dict'])
print(load_pkl)
# Out:
# /home/wangc/now/NaviAirway/checkpoint/abc_checkpoint_sample_org_33.pkl

# %% [markdown]
# ### 需要调整样本数量就修改下面的N即可

# %% [markdown]
# ### 使用embedding网络进行encode

# %%
from active_learning_utils import process_images
N=len(raw_case_name_list)
embeddings_list, embeddings_dict=process_images(Precrop_dataset_for_train_path,raw_case_name_list, N, model, device,
                                                only_positive=True
                                                )
# 将列表中的NumPy数组堆叠成一个NumPy数组
stacked_embeddings_numpy = np.stack(embeddings_list, axis=0)
print(stacked_embeddings_numpy.shape)  # 输出应为 [N, 256, 4, 16, 16]

file_path = '/home/wangc/now/NaviAirway/saved_var/exact09_128_embeddings_data.pkl'
# 确保文件夹存在，如果不存在则创建它
os.makedirs(os.path.dirname(file_path), exist_ok=True)

# 保存到文件
with open(file_path, 'wb') as file:
    data_to_save = {'embeddings_list': embeddings_list, 'embeddings_dict': embeddings_dict}
    pickle.dump(data_to_save, file)

# %%
from active_learning_utils import process_images
embeddings_list, embeddings_dict=process_images(Precrop_dataset_for_train_path,raw_case_name_list, N, model, device,
                                                only_positive=True
                                                )
# 将列表中的NumPy数组堆叠成一个NumPy数组
stacked_embeddings_numpy = np.stack(embeddings_list, axis=0)
print(stacked_embeddings_numpy.shape)  # 输出应为 [N, 256, 4, 16, 16]

file_path = '/home/wangc/now/NaviAirway/saved_var/op_exact09_256_embeddings_data.pkl'
# 确保文件夹存在，如果不存在则创建它
os.makedirs(os.path.dirname(file_path), exist_ok=True)

# # 保存到文件
# with open(file_path, 'wb') as file:
#     data_to_save = {'embeddings_list': embeddings_list, 'embeddings_dict': embeddings_dict}
#     pickle.dump(data_to_save, file)

# %%
file_path = '/home/wangc/now/NaviAirway/saved_var/exact09_256_embeddings_data.pkl'
with open(file_path, 'rb') as file:
    loaded_data = pickle.load(file)
    embeddings_list1 = loaded_data['embeddings_list']
    embeddings_dict1 = loaded_data['embeddings_dict']
stacked_embeddings_numpy1 = np.stack(embeddings_list1, axis=0)
file_path = '/home/wangc/now/NaviAirway/saved_var/lidc_256_embeddings_data.pkl'
with open(file_path, 'rb') as file:
    loaded_data = pickle.load(file)
    embeddings_list2 = loaded_data['embeddings_list']
    embeddings_dict2 = loaded_data['embeddings_dict']
stacked_embeddings_numpy2 = np.stack(embeddings_list2, axis=0)

# %% [markdown]
# ### 和上面一样，这个是使用gpu加速的同一方法

# %% [markdown]
# ### 将stacked_embeddings_numpy转为torch张量并进行reshape

# %%
X = torch.from_numpy(stacked_embeddings_numpy)
N=X.shape[0]
X_t = X.reshape(N, -1)

# %%
X_t.shape
# Out:
# torch.Size([1140, 262144])

# %% [markdown]
# ### 聚类 然后 Tsne

# %%
from sklearn.cluster import KMeans

# 对 X_t 进行 K-Means 聚类
num_clusters = 2#2
kmeans = KMeans(n_clusters=num_clusters, random_state=0)
cluster_labels = kmeans.fit_predict(X_t)

# 将聚类结果添加到 X_t 中作为最后一列
X_t_with_labels = np.column_stack((X_t, cluster_labels))
# Out:
# /home/wangc/anaconda3/envs/test1/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
X_t.shape, cluster_labels.shape
# Out:
# (torch.Size([1140, 262144]), (1184,))

# %% [markdown]
# ### 2d Tsne

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors


# 使用 perplexity 为 50 的 t-SNE 进行嵌入
tsne = TSNE(n_components=2, perplexity=70)
X_embedded_2d = tsne.fit_transform(X_t_with_labels)
embedding_dict = {raw_case_name_list[i]: X_embedded_2d[i] for i in range(N)}


# 使用 t-SNE 进行降维
threshold_dim1 = 200  # 调整阈值
threshold_dim2 = 200  # 调整阈值

# 筛选出维度值在一定范围内的数据
filtered_indices = np.where((abs(X_embedded_2d[:, 0]) < threshold_dim1) & (abs(X_embedded_2d[:, 1]) < threshold_dim2))[0]

# 筛选出符合阈值的数据
filtered_embeddings = X_embedded_2d[filtered_indices]


# 绘制二维散点图，只绘制符合阈值的数据
# 可视化二维嵌入并根据聚类标签着色
# colors = list(mcolors.TABLEAU_COLORS.values())
# custom_cmap = mcolors.ListedColormap(colors)


unique_labels = np.unique(cluster_labels)
cmap = plt.get_cmap('viridis', len(unique_labels))
colors = [cmap(i) for i in range(len(unique_labels))]

# 使用 ListedColormap 为不同的聚类簇指定颜色
custom_cmap = ListedColormap(colors)
plt.figure(figsize=(8, 6), dpi=100)
plt.scatter(filtered_embeddings[:, 0], filtered_embeddings[:, 1], c=cluster_labels[filtered_indices], cmap=custom_cmap)
plt.title("t-SNE 2D Embedding with Cluster Coloring (Perplexity=70)")
# # 定义自定义的颜色映射

# sm = plt.cm.ScalarMappable(cmap=custom_cmap, norm=plt.Normalize(vmin=cluster_labels.min(), vmax=cluster_labels.max()))
# sm._A = []  # 设置一个空的数组
plt.show()

# %% [markdown]
# ### 3d Tsne

# %%
# 使用 t-SNE 进行降维
tsne = TSNE(n_components=3, perplexity=70, random_state=0)
X_embedded_3d = tsne.fit_transform(X_t)

unique_labels = np.unique(cluster_labels)
cmap = plt.get_cmap('viridis', len(unique_labels))
colors = [cmap(i) for i in range(len(unique_labels))]

# 使用 ListedColormap 为不同的聚类簇指定颜色
custom_cmap = ListedColormap(colors)

# 可视化三维嵌入并根据聚类标签着色
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')  # 创建3D图的坐标轴对象

ax.scatter(X_embedded_3d[:, 0], X_embedded_3d[:, 1], X_embedded_3d[:, 2], c=cluster_labels, cmap=custom_cmap)
ax.set_title("t-SNE 3D Embedding with Cluster Coloring (Perplexity=70)")
ax.set_xlabel("Dimension 1")
ax.set_ylabel("Dimension 2")
ax.set_zlabel("Dimension 3")
plt.colorbar()
plt.savefig('scatter_plot_3d_colored.png')
plt.show()

# %% [markdown]
# ### 如果想索引对应的点，可以使用这里的代码

# %%
from matplotlib.colors import ListedColormap


X_t=np.array(list(embeddings_dict.values())).reshape(N,-1)
kmeans = KMeans(n_clusters=2, random_state=0)
cluster_labels = kmeans.fit_predict(X_t)



tsne = TSNE(n_components=2, perplexity=70, random_state=0)
X_embedded_2d = tsne.fit_transform(X_t)

# 使用 t-SNE 进行降维
threshold_dim1 = 100  # 调整阈值
threshold_dim2 = 100  # 调整阈值

# 筛选出维度值在一定范围内的数据

filtered_indices = np.where((abs(X_embedded_2d[:, 0]) < threshold_dim1) & (abs(X_embedded_2d[:, 1]) < threshold_dim2))[0]
# 筛选出符合阈值的数据
filtered_embeddings = X_embedded_2d[filtered_indices]

# 提取嵌入坐标和对应的名称
names = list(embeddings_dict.keys())

names_filtered = [names[i] for i in filtered_indices]


unique_labels = np.unique(cluster_labels)
cmap = plt.get_cmap('viridis', len(unique_labels))
colors = [cmap(i) for i in range(len(unique_labels))]

# 使用 ListedColormap 为不同的聚类簇指定颜色
custom_cmap = ListedColormap(colors)

# 清除之前的图像，以防止重叠
plt.clf()

# 在每个点上标记对应的名称

# 绘制二维散点图，只绘制符合阈值的数据
# 可视化二维嵌入并根据聚类标签着色
plt.figure(figsize=(20, 16), dpi=100)
for i in range(len(filtered_indices)):
    # name = names_filtered[i]
    plt.annotate(i, (filtered_embeddings[i, 0], filtered_embeddings[i, 1]), fontsize=8, alpha=0.7)

plt.scatter(filtered_embeddings[:, 0], filtered_embeddings[:, 1], c=cluster_labels[filtered_indices], cmap=custom_cmap)
plt.title("t-SNE 2D Embedding with Cluster Coloring (Perplexity=70)")
sm = plt.cm.ScalarMappable(cmap=custom_cmap, norm=plt.Normalize(vmin=cluster_labels.min(), vmax=cluster_labels.max()))
sm._A = []  # 设置一个空的数组
# plt.show()

# %%
print(N)
# Out:
# 8832

# %%
from matplotlib.colors import ListedColormap


X_t=np.array(list(embeddings_dict.values())).reshape(N,-1)
kmeans = KMeans(n_clusters=3, random_state=0)
cluster_labels = kmeans.fit_predict(X_t)



tsne = TSNE(n_components=2, perplexity=70, random_state=0)
X_embedded_2d = tsne.fit_transform(X_t)
# Out:
# /home/cs22-wangc/anaconda3/envs/test1/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
from matplotlib.colors import ListedColormap
import numpy as np
import matplotlib.pyplot as plt

def visualize_and_return_indices(X_embedded_2d, cluster_labels, embeddings_dict, x1=100,y1=100,
                                 x2=None,y2=None,selected_indices=None,show_index=False):



    if x2 is None and y2 is None:
        filtered_indices = np.where((abs(X_embedded_2d[:, 0]) < abs(x1)) & (abs(X_embedded_2d[:, 1]) < abs(y1)))[0]
    
    else:

        # 创建布尔索引
        x_condition = (X_embedded_2d[:, 0] >= x1) & (X_embedded_2d[:, 0] <= x2)
        y_condition = (X_embedded_2d[:, 1] >= y1) & (X_embedded_2d[:, 1] <= y2)#纵轴
    
        # 通过两个条件的逻辑与来筛选元素
        filtered_indices = np.where(x_condition & y_condition)[0]
    print('filtered_indices',len(filtered_indices))
    if selected_indices is not None:
        intersection_set = set(filtered_indices).intersection(selected_indices)
        filtered_indices = list(intersection_set)
        print('selected_indices',len(filtered_indices))
    # 筛选出符合阈值的数据
    filtered_embeddings = X_embedded_2d[filtered_indices]
    

    # 提取嵌入坐标和对应的名称
    names = list(embeddings_dict.keys())
    names_filtered = [names[i] for i in filtered_indices]
    unique_labels = np.unique(cluster_labels[filtered_indices])
    cmap = plt.get_cmap('viridis', len(unique_labels))
    colors = [cmap(i) for i in range(len(unique_labels))]
    custom_cmap = ListedColormap(colors)
    
    # 清除之前的图像，以防止重叠
    plt.clf()
    
    # 绘制图像
    plt.figure(figsize=(8, 6), dpi=100)
    if show_index is True:
        for i, j in enumerate(filtered_indices):
            plt.annotate(j, (filtered_embeddings[i, 0], filtered_embeddings[i, 1]), fontsize=8, alpha=0.7)
        # print(i)



    num_classes = len(unique_labels)
    random_colors = np.random.rand(num_classes, 3)
    custom_cmap = ListedColormap(random_colors)

    plt.scatter(filtered_embeddings[:, 0], filtered_embeddings[:, 1], c=cluster_labels[filtered_indices], cmap=custom_cmap)
    print('filtered_embeddings.shape',filtered_embeddings.shape)
    plt.title("t-SNE 2D Embedding with Cluster Coloring (Perplexity=70)")
    # sm = plt.cm.ScalarMappable(cmap=custom_cmap, norm=plt.Normalize(vmin=cluster_labels.min(), vmax=cluster_labels.max()))
    # sm._A = []  # 设置一个空的数组
    
    # 保存图片
    plt.savefig("visualization.png")
    
    # 返回结果
    return filtered_indices, names_filtered

# %%
# # print(len(class_0_indices),len(class_1_indices),len(filtered_indices))
all_indices,_ = visualize_and_return_indices(X_embedded_2d, cluster_labels, embeddings_dict,
                                   x1=100,y1=100,x2=None,y2=None,selected_indices=None)
# Out:
# filtered_indices 1092
# filtered_embeddings.shape (1092, 2)

# %%
class_0_indices = np.where(cluster_labels == 0)[0]
class_1_indices = np.where(cluster_labels == 1)[0]
class_2_indices = np.where(cluster_labels == 2)[0]
print(0 in cluster_labels[class_1_indices])
print(1 in cluster_labels[class_0_indices])
print(1 in cluster_labels[class_2_indices])
# # 将列表转换为集合，然后求交集
# intersection_set = set(class_0_indices).intersection(class_1_indices)

# intersection_list = list(intersection_set)  # 将交集的集合转换回列表
# print('num',len(class_0_indices),len(class_1_indices))
# print("交集：", intersection_list)
# Out:
# False
# False
# False

# %%
class_0_indices,class_0_names_filtere = visualize_and_return_indices(
    X_embedded_2d, cluster_labels, embeddings_dict,
    selected_indices=class_0_indices)
# Out:
# filtered_indices 1092
# selected_indices 280
# filtered_embeddings.shape (280, 2)

# %%
class_1_indices, class1_names_filtered = visualize_and_return_indices(X_embedded_2d, 
                                                                        cluster_labels, embeddings_dict,
                                                                        x1=100,y1=100,x2=None,y2=None,selected_indices=class_1_indices)
# Out:
# filtered_indices 1092
# selected_indices 529
# filtered_embeddings.shape (529, 2)

# %%
class_2_indices, class2_names_filtered = visualize_and_return_indices(X_embedded_2d, 
                                                                        cluster_labels, embeddings_dict,
                                                                        x1=100,y1=100,x2=None,y2=None,selected_indices=class_2_indices)
# Out:
# filtered_indices 1092
# selected_indices 283
# filtered_embeddings.shape (283, 2)

# %% [markdown]
# ### 将所需要的patch从原来的数据集抽取出来

# %%
import subprocess
import time
def generate_folder_for_selected(source, #原数据集位置
                                 target, #目的路径
                                 selected_name, #要进行选择的name
                                 num=None): #如果只是想看一部分，而不是选择全部，设置num即可
    address1 = ["/image", "/label"]

    for adr in address1:
        source_path = source+adr
        target_path = target+adr
        os.makedirs(target_path, exist_ok=True)
        if num is None:# 如果 num 未指定，默认为选定名称的长度
            num=len(selected_name)
        for i in range(num):
            print(f"{i/num*100:.2f}%", end="\r")
            time.sleep(0.5)  # 模拟耗时操作
            file_name = selected_name[i]
            source_file = os.path.join(source_path, file_name)
            target_file = os.path.join(target_path, file_name)  
            subprocess.run(['cp', source_file, target_file])## 复制文件到目标路径

# %%
source_folder = '/mnt/share102/cs22-wangc/EXACT09/Precrop_dataset_for_EXACT091'
target_folder = '/mnt/share102/cs22-wangc/EXACT09/op_Cluster/class1'
generate_folder_for_selected(source_folder, target_folder,class1_names_filtered,)
# class1_names_filtered,names_filtered_end,arc_name,triple_arc_name
# Out:
# 99.81%

# %%
source_folder = '/mnt/share102/cs22-wangc/EXACT09/Precrop_dataset_for_EXACT091'
target_folder = '/mnt/share102/cs22-wangc/EXACT09/op_Cluster/class0'
generate_folder_for_selected(source_folder, target_folder,class_0_names_filtere)
# Out:
# 99.64%

# %%
source_folder = '/mnt/share102/cs22-wangc/EXACT09/Precrop_dataset_for_EXACT091'
target_folder = '/mnt/share102/cs22-wangc/EXACT09/op_Cluster/class2'
generate_folder_for_selected(source_folder, target_folder,class2_names_filtered)
# Out:
# 99.65%

# %%
source_folder = '/mnt/share102/cs22-wangc/EXACT09/Precrop_dataset_for_EXACT091'
target_folder = '/mnt/share102/cs22-wangc/EXACT09/Cluster/filtered_end'
generate_folder_for_selected(source_folder, target_folder,names_filtered_end,num=600)
# Out:
# 99.83%

# %%
def show_all_2d_img_with_labels(raw_img_path, output_folder, img_num=None, 
                                num_images_per_batch=16, slice_index=20, label_path=None):
    """
    将raw_img_path的图像读出，这是一些3d图像，每个图像取slice_index对应位置的2d切片，
    根据下面num_rows = 4，num_cols = 4，将这些切片排列在一张图上，如果label_path不为None，则从对应文件夹读出label图像，进行标注
    """
    raw_img_list = os.listdir(raw_img_path)
    if img_num is None:
        img_num = len(raw_img_list)
    img_num = min(img_num, len(raw_img_list))
    num_batches = (img_num + num_images_per_batch - 1) // num_images_per_batch  # 上取整

    num_rows = 4
    num_cols = 4
    
    # 检查并创建输出文件夹
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    for batch_num in range(num_batches):
        start_index = batch_num * num_images_per_batch
        end_index = min((batch_num + 1) * num_images_per_batch, img_num)
        
        img_list = []
        for i in range(start_index, end_index):
            raw_img_addr = os.path.join(raw_img_path, raw_img_list[i])
            raw_img = io.imread(raw_img_addr, plugin='simpleitk')
            img_list.append(raw_img)
            print(f'11img_selecting {100 * (i+1) / img_num:.2f}%', end='\r')
        
        # 创建一个包含16个子图的图像窗口
        fig, axes = plt.subplots(num_rows, num_cols, figsize=(20, 20))
        fig.suptitle(f"Batch {batch_num+1} - Raw Images")
        
        for i in range(num_rows):
            for j in range(num_cols):
                index = i * num_cols + j
                if index < len(img_list):
                    raw_img = img_list[index]
                    ax = axes[i, j]
                    
                    ax.imshow(raw_img[slice_index, :, :], cmap='gray')
                    
                    if label_path is not None:
                        label_img_addr = os.path.join(label_path, raw_img_list[index])
                        label_img = io.imread(label_img_addr, plugin='simpleitk')
                        if 1 not in label_img:
                            ax.text(0.8, 0.9, "No Label", transform=ax.transAxes, color='g', fontsize=12, fontweight='bold')
                        ax.contour(label_img[slice_index, :, :], colors='r', linestyles='-')
                    
                    ax.set_title(f"img_list index {index}")
                    ax.axis('off')
        
        # 调整子图之间的间距和布局
        plt.subplots_adjust(wspace=0.1, hspace=0.3)
        
        # 保存图像
        plt.savefig(os.path.join(output_folder, f"output_images_batch_{batch_num+1}.png"))
        
        # 关闭图像窗口，避免重叠
        plt.close()
all_path='/mnt/share102/cs22-wangc/EXACT09/Cluster'
sub_folders = [folder_name for folder_name in os.listdir(all_path) if os.path.isdir(os.path.join(all_path, folder_name))]
sub_folders=['only_right_1','only_right_0',]
for path in sub_folders:
    address1 = ["/image", "/label"]
    raw_img_folder=all_path+'/'+path+address1[0]
    label_path= all_path+'/'+path+address1[1]
    print('this is ',path)
    slice_folder='/home/cs22-wangc/now/slice_folder'+'/'+str(path)

    show_all_2d_img_with_labels(raw_img_folder,slice_folder,img_num=2000,label_path=label_path)

sub_folders
# Out:
# this is  only_right_1
# this is  only_right_00%
# 11img_selecting 100.00%
# ['only_right_1', 'only_right_0']

# %%
def get_label_airway_pixels(label_img, slice_index=None):
    if slice_index is not None:
        if 1 not in label_img[slice_index, :, :]:
            j = 0
            while j < label_img.shape[0] and 1 not in label_img[j, :, :]:
                j += 1
            if j>= label_img.shape[0]:
                j=j-1
            return label_img[j, :, :].sum()
        else:
            return label_img[slice_index, :, :].sum()
    else:
        return label_img.sum()

def analysis_cluster(label_path, slice_index=None):
    label_img_list = os.listdir(label_path)
    pixels_num_list = []
    
    for name in label_img_list:
        label_img_addr = os.path.join(label_path, name)
        label_img = io.imread(label_img_addr, plugin='simpleitk')
        pixels_num = get_airway_pixels(label_img, slice_index)
        pixels_num_list.append(pixels_num)

    # 使用numpy计算均值和方差
    mean_value = np.mean(pixels_num_list)
    std_deviation = np.std(pixels_num_list)
    N = len(pixels_num_list)  # 总体数据点数量
    # total_std_deviation = np.sqrt(np.sum((pixels_num_list - mean_value) ** 2) / N)

    return mean_value, std_deviation#均值和标准差

all_path = "/mnt/wangc/EXACT09/cluster_folder"
sub_folders = [folder_name for folder_name in os.listdir(all_path) if os.path.isdir(os.path.join(all_path, folder_name))]
for sub_name in sub_folders:
    class_num=['class1','class0']
    for i in class_num:
        end_path=all_path+'/'+sub_name+'/'+i+"/label"
        label_img_list=os.listdir(str(end_path))
        a,b=analysis_cluster(label_img_list)
        print(f"{sub_name} 's {class_num} a,b")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 40
#      38 end_path=all_path+'/'+sub_name+'/'+i+"/label"
#      39 label_img_list=os.listdir(str(end_path))
# ---> 40 a,b=analysis_cluster(label_img_list)
#      41 print(f"{sub_name} 's {class_num} a,b")
#
# Cell In[52], line 16, in analysis_cluster(label_path, slice_index)
#      15 def analysis_cluster(label_path, slice_index=None):
# ---> 16     label_img_list = os.listdir(label_path)
#      17     pixels_num_list = []
#      19     for name in label_img_list:
#
# TypeError: listdir: path should be string, bytes, os.PathLike, integer or None, not list
